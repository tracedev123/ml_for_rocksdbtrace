# %%
# !pip install ctgan
from ctgan import CTGAN
from google.colab import drive
from natsort import natsorted
from prettytable import PrettyTable
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import accuracy_score, r2_score
import numpy as np
import os
import pandas as pd
import warnings
drive.mount('/content/drive')
warnings.filterwarnings('ignore')
root_folder = '/content/drive/MyDrive/aaa/datasets'
def find_and_sort_csv_files(folder):
    csv_files = []
    for root, dirs, files in os.walk(folder):
        for file in files:
            if file.endswith('.csv'):
                csv_files.append(os.path.join(root, file))
    csv_files_sorted = natsorted(csv_files)
    return csv_files_sorted
all_csv_files_sorted = find_and_sort_csv_files(root_folder)
feature_name = 'HISTORY' ########################################################
test_ratio_in_percentage = 20 ########################################################
test_ratio = test_ratio_in_percentage / 100 ########################################################
table = PrettyTable()
table.field_names = ["Location", "Average Score"]
for csv_file in all_csv_files_sorted:
    file_path = os.path.join(root_folder, csv_file)
    data = pd.read_csv(file_path)
    data = data.head(int(np.round(len(data) * 0.001)))
    data = data.reset_index()
    test_size = int(np.round(len(data) * test_ratio))
    train_data, test_data = data[:-test_size], data[-test_size:]
    num_columns = train_data.shape[1]
    prediction_indices = range(len(train_data), len(train_data) + test_size)
    prediction_data = pd.DataFrame(prediction_indices, columns=['index'], index=prediction_indices)
    for col in [column for column in train_data.columns if train_data[column].nunique() == 1]:
        prediction_data[col] = pd.Series(train_data[col].iloc[0]).repeat(test_size).values
    columns_not_in_prediction = [col for col in train_data.columns.tolist() if col not in prediction_data.columns.tolist()]
    unique_values_dict = {}
    for col in columns_not_in_prediction:
        unique_values = train_data[col].nunique()
        unique_values_dict[col] = unique_values
    continuous_columns = []
    discrete_columns = []
    for col, unique_values in unique_values_dict.items():
        if unique_values > 500:
            continuous_columns.append(col)
        else:
            discrete_columns.append(col)
    model = CTGAN(verbose=False)
    model.fit(train_data, discrete_columns, epochs=50)
    ctgan_data = model.sample(test_size)
    ctgan_data = ctgan_data.sort_values(by='time', ascending=True)
    num_past_measurements = 20
    start_index = len(data) - test_size
    for col in columns_not_in_prediction:
        for i in range(1, num_past_measurements + 1):
            data[f'{col}_{i}'] = data[col].shift(i * 25)
            if data[f'{col}_{i}'].dtype == 'int64':
                data[f'{col}_{i}'].fillna(-1, inplace=True)
            elif data[f'{col}_{i}'].dtype == 'float64':
                data[f'{col}_{i}'].fillna(-1.0, inplace=True)
            if data[f'{col}_{i}'].dtype != data[col].dtype:
                data[f'{col}_{i}'] = data[f'{col}_{i}'].astype(data[col].dtype)
            train_data.loc[:start_index, f'{col}_{i}'] = data.loc[:start_index, f'{col}_{i}']
            test_data.loc[:start_index, f'{col}_{i}'] = data.loc[:start_index, f'{col}_{i}']
            prediction_data.loc[start_index:, f'{col}_{i}'] = data.loc[start_index:, f'{col}_{i}']
    num_rows = int(np.round(len(train_data) * 0.05))
    for col in columns_not_in_prediction:
        if col in continuous_columns:
            features = [f'{col}_{i}' for i in range(1, num_columns)]
            X_test = prediction_data[features]
            X_train = train_data[features].values[-num_rows:]
            y_train = train_data[col].values[-num_rows:]
            model = LinearRegression()
            model.fit(X_train, y_train)
            y_pred = model.predict(X_test)
            y_pred = np.where(y_pred < -1, -1, y_pred)
            if train_data[col].dtype == np.int64:
                y_pred = np.round(y_pred).astype(np.int64)
            prediction_data[col] = y_pred
    for col in ctgan_data.columns:
        if col not in prediction_data.columns:
            prediction_data[col] = ctgan_data[col].values
    columns_to_drop = ['index']
    if columns_not_in_prediction:
        start_index = train_data.columns.get_loc(f'{columns_not_in_prediction[0]}_1')
        end_index = train_data.columns.get_loc(f'{columns_not_in_prediction[-1]}_{num_past_measurements}')
        columns_to_drop.extend(data.columns[start_index:end_index + 1])
    data = data.drop(columns_to_drop, axis=1)
    train_data = train_data.drop(columns_to_drop, axis=1)
    test_data = test_data.drop(columns_to_drop, axis=1)
    prediction_data = prediction_data.drop(columns_to_drop, axis=1)
    prediction_data = prediction_data[train_data.columns]
    scores = {}
    for col in prediction_data.columns:
        if col in continuous_columns:
            score = r2_score(test_data[col], prediction_data[col])
            if score < 0:
                score = 0
            metric = 'R-squared'
        else:
            score = accuracy_score(test_data[col], prediction_data[col])
            metric = 'Accuracy'
        scores[col] = (score, metric)
    average_score = np.mean([score for score, metric in scores.values()])
    average_score = round(average_score * 100, 2)
    table.add_row([file_path, f'{average_score}%'])
    table.add_row([''] * len(table.field_names))
print(table)
# Out:
# Requirement already satisfied: ctgan in /usr/local/lib/python3.10/dist-packages (0.8.0)
# Requirement already satisfied: tqdm<5,>=4.15 in /usr/local/lib/python3.10/dist-packages (from ctgan) (4.66.1)
# Requirement already satisfied: rdt<2.0,>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from ctgan) (1.9.1)
# Requirement already satisfied: numpy<2,>=1.23.3 in /usr/local/lib/python3.10/dist-packages (from ctgan) (1.23.5)
# Requirement already satisfied: scikit-learn<2,>=1.1.3 in /usr/local/lib/python3.10/dist-packages (from ctgan) (1.2.2)
# Requirement already satisfied: pandas>=1.3.4 in /usr/local/lib/python3.10/dist-packages (from ctgan) (1.5.3)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from ctgan) (2.1.0+cu121)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.4->ctgan) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.4->ctgan) (2023.3.post1)
# Requirement already satisfied: Faker<20,>=17 in /usr/local/lib/python3.10/dist-packages (from rdt<2.0,>=1.6.1->ctgan) (19.13.0)
# Requirement already satisfied: scipy<2,>=1.9.2 in /usr/local/lib/python3.10/dist-packages (from rdt<2.0,>=1.6.1->ctgan) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2,>=1.1.3->ctgan) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2,>=1.1.3->ctgan) (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan) (2.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.3.4->ctgan) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->ctgan) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->ctgan) (1.3.0)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# +--------------------------------------------------------------------------+---------------+
# |                                 Location                                 | Average Score |
# +--------------------------------------------------------------------------+---------------+
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/iolt_1.csv   |     85.64%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/iolt_2.csv   |     33.83%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/qlt_1.csv    |     80.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/qlt_2.csv    |     80.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/iolt_1.csv   |     85.23%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/iolt_2.csv   |     86.41%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/qlt.csv     |     79.98%    |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/iolt_1.csv      |     85.81%    |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/iolt_2.csv      |     78.04%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/qlt.csv       |     100.0%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/db_bench/mixgraph/iolt.csv      |     49.8%     |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/db_bench/mixgraph/qlt.csv       |     45.13%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_1/bclt.csv       |     75.79%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_1/qlt.csv        |     79.62%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_2/bclt.csv       |     74.85%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_2/qlt.csv        |     79.95%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/iolt.csv    |     58.31%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/qlt.csv     |     79.96%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_2/qlt.csv     |     63.63%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_3/qlt.csv     |     64.24%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_4/bclt.csv    |     71.63%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_4/iolt.csv    |     62.25%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_4/qlt.csv     |     63.42%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_5/bclt.csv    |     74.79%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_5/qlt.csv     |     79.74%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_6/qlt.csv     |     100.0%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_7/qlt.csv     |     79.4%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_8/bclt.csv    |     75.6%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_8/qlt.csv     |     79.78%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_1.csv   |     76.41%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_2.csv   |     70.3%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_3.csv   |     70.72%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_4.csv   |     70.81%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_5.csv   |     70.39%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_6.csv   |     69.71%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_7.csv   |     70.99%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_8.csv   |     71.73%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/iolt.csv    |     59.88%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/qlt.csv     |     79.97%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/bclt.csv     |     84.84%    |
# |                                                                          |               |
# | /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/bclt_replay.csv |     83.61%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/iolt.csv     |     72.01%    |
# |                                                                          |               |
# | /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/iolt_replay.csv |     46.82%    |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/qlt.csv     |     62.06%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/bclt_1.csv    |     55.36%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/bclt_2.csv    |     58.18%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/iolt.csv     |     59.31%    |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/qlt.csv     |     62.72%    |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_3/qlt.csv     |     58.9%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_1/bclt.csv   |     75.76%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_1/qlt.csv    |     60.11%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_2/bclt.csv   |     74.78%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_2/qlt.csv    |     61.68%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_3/bclt.csv   |     75.01%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_3/qlt.csv    |     60.32%    |
# |                                                                          |               |
# |            /content/drive/MyDrive/aaa/datasets/redis/bclt.csv            |     82.78%    |
# |                                                                          |               |
# |            /content/drive/MyDrive/aaa/datasets/redis/iolt.csv            |     31.32%    |
# |                                                                          |               |
# |            /content/drive/MyDrive/aaa/datasets/redis/qlt.csv             |     99.85%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_1.csv       |     53.87%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_2.csv       |     48.34%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_3.csv       |     49.12%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_4.csv       |     48.11%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_5.csv       |     48.87%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_6.csv       |     48.58%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_7.csv       |     48.2%     |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/ycsb/workloada/qlt_1.csv       |     100.0%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/ycsb/workloada/qlt_2.csv       |     71.71%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/ycsb/workloadc/bclt.csv        |     80.88%    |
# |                                                                          |               |
# |        /content/drive/MyDrive/aaa/datasets/ycsb/workloadc/qlt.csv        |     68.63%    |
# |                                                                          |               |
# +--------------------------------------------------------------------------+---------------+

# %%
feature_name = 'HISTORY' ########################################################
test_ratio_in_percentage = 50 ########################################################
test_ratio = test_ratio_in_percentage / 100 ########################################################
table = PrettyTable()
table.field_names = ["Location", "Average Score"]
for csv_file in all_csv_files_sorted:
    file_path = os.path.join(root_folder, csv_file)
    data = pd.read_csv(file_path)
    data = data.head(int(np.round(len(data) * 0.001)))
    data = data.reset_index()
    test_size = int(np.round(len(data) * test_ratio))
    train_data, test_data = data[:-test_size], data[-test_size:]
    num_columns = train_data.shape[1]
    prediction_indices = range(len(train_data), len(train_data) + test_size)
    prediction_data = pd.DataFrame(prediction_indices, columns=['index'], index=prediction_indices)
    for col in [column for column in train_data.columns if train_data[column].nunique() == 1]:
        prediction_data[col] = pd.Series(train_data[col].iloc[0]).repeat(test_size).values
    columns_not_in_prediction = [col for col in train_data.columns.tolist() if col not in prediction_data.columns.tolist()]
    unique_values_dict = {}
    for col in columns_not_in_prediction:
        unique_values = train_data[col].nunique()
        unique_values_dict[col] = unique_values
    continuous_columns = []
    discrete_columns = []
    for col, unique_values in unique_values_dict.items():
        if unique_values > 500:
            continuous_columns.append(col)
        else:
            discrete_columns.append(col)
    model = CTGAN(verbose=False)
    model.fit(train_data, discrete_columns, epochs=50)
    ctgan_data = model.sample(test_size)
    ctgan_data = ctgan_data.sort_values(by='time', ascending=True)
    num_past_measurements = 20
    start_index = len(data) - test_size
    for col in columns_not_in_prediction:
        for i in range(1, num_past_measurements + 1):
            data[f'{col}_{i}'] = data[col].shift(i * 25)
            if data[f'{col}_{i}'].dtype == 'int64':
                data[f'{col}_{i}'].fillna(-1, inplace=True)
            elif data[f'{col}_{i}'].dtype == 'float64':
                data[f'{col}_{i}'].fillna(-1.0, inplace=True)
            if data[f'{col}_{i}'].dtype != data[col].dtype:
                data[f'{col}_{i}'] = data[f'{col}_{i}'].astype(data[col].dtype)
            train_data.loc[:start_index, f'{col}_{i}'] = data.loc[:start_index, f'{col}_{i}']
            test_data.loc[:start_index, f'{col}_{i}'] = data.loc[:start_index, f'{col}_{i}']
            prediction_data.loc[start_index:, f'{col}_{i}'] = data.loc[start_index:, f'{col}_{i}']
    num_rows = int(np.round(len(train_data) * 0.05))
    for col in columns_not_in_prediction:
        if col in continuous_columns:
            features = [f'{col}_{i}' for i in range(1, num_columns)]
            X_test = prediction_data[features]
            X_train = train_data[features].values[-num_rows:]
            y_train = train_data[col].values[-num_rows:]
            model = LinearRegression()
            model.fit(X_train, y_train)
            y_pred = model.predict(X_test)
            y_pred = np.where(y_pred < -1, -1, y_pred)
            if train_data[col].dtype == np.int64:
                y_pred = np.round(y_pred).astype(np.int64)
            prediction_data[col] = y_pred
    for col in ctgan_data.columns:
        if col not in prediction_data.columns:
            prediction_data[col] = ctgan_data[col].values
    columns_to_drop = ['index']
    if columns_not_in_prediction:
        start_index = train_data.columns.get_loc(f'{columns_not_in_prediction[0]}_1')
        end_index = train_data.columns.get_loc(f'{columns_not_in_prediction[-1]}_{num_past_measurements}')
        columns_to_drop.extend(data.columns[start_index:end_index + 1])
    data = data.drop(columns_to_drop, axis=1)
    train_data = train_data.drop(columns_to_drop, axis=1)
    test_data = test_data.drop(columns_to_drop, axis=1)
    prediction_data = prediction_data.drop(columns_to_drop, axis=1)
    prediction_data = prediction_data[train_data.columns]
    scores = {}
    for col in prediction_data.columns:
        if col in continuous_columns:
            score = r2_score(test_data[col], prediction_data[col])
            if score < 0:
                score = 0
            metric = 'R-squared'
        else:
            score = accuracy_score(test_data[col], prediction_data[col])
            metric = 'Accuracy'
        scores[col] = (score, metric)
    average_score = np.mean([score for score, metric in scores.values()])
    average_score = round(average_score * 100, 2)
    table.add_row([file_path, f'{average_score}%'])
    table.add_row([''] * len(table.field_names))
print(table)
# Out:
# +--------------------------------------------------------------------------+---------------+
# |                                 Location                                 | Average Score |
# +--------------------------------------------------------------------------+---------------+
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/iolt_1.csv   |     86.11%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/iolt_2.csv   |     34.77%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/qlt_1.csv    |     80.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/qlt_2.csv    |     80.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/iolt_1.csv   |     84.83%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/iolt_2.csv   |     86.16%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/qlt.csv     |     80.0%     |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/iolt_1.csv      |     86.27%    |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/iolt_2.csv      |     77.76%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/qlt.csv       |     100.0%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/db_bench/mixgraph/iolt.csv      |     52.62%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/db_bench/mixgraph/qlt.csv       |     36.68%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_1/bclt.csv       |     75.29%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_1/qlt.csv        |     79.82%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_2/bclt.csv       |     75.14%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_2/qlt.csv        |     79.77%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/iolt.csv    |     58.5%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/qlt.csv     |     79.85%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_2/qlt.csv     |     63.8%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_3/qlt.csv     |     63.6%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_4/bclt.csv    |     66.72%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_4/iolt.csv    |     62.43%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_4/qlt.csv     |     62.85%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_5/bclt.csv    |     75.43%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_5/qlt.csv     |     79.79%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_6/qlt.csv     |     99.97%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_7/qlt.csv     |     79.98%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_8/bclt.csv    |     75.57%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_8/qlt.csv     |     79.4%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_1.csv   |     74.62%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_2.csv   |     70.18%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_3.csv   |     71.52%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_4.csv   |     70.94%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_5.csv   |     69.67%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_6.csv   |     71.34%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_7.csv   |     71.27%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_8.csv   |     71.24%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/iolt.csv    |     60.5%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/qlt.csv     |     79.89%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/bclt.csv     |     83.93%    |
# |                                                                          |               |
# | /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/bclt_replay.csv |     84.13%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/iolt.csv     |     71.74%    |
# |                                                                          |               |
# | /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/iolt_replay.csv |     48.81%    |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/qlt.csv     |     62.54%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/bclt_1.csv    |     56.18%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/bclt_2.csv    |     59.9%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/iolt.csv     |     54.14%    |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/qlt.csv     |     48.44%    |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_3/qlt.csv     |     59.83%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_1/bclt.csv   |     75.89%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_1/qlt.csv    |     56.66%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_2/bclt.csv   |     75.84%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_2/qlt.csv    |     59.88%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_3/bclt.csv   |     72.16%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_3/qlt.csv    |     58.73%    |
# |                                                                          |               |
# |            /content/drive/MyDrive/aaa/datasets/redis/bclt.csv            |     83.17%    |
# |                                                                          |               |
# |            /content/drive/MyDrive/aaa/datasets/redis/iolt.csv            |     33.13%    |
# |                                                                          |               |
# |            /content/drive/MyDrive/aaa/datasets/redis/qlt.csv             |     99.8%     |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_1.csv       |     52.74%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_2.csv       |     48.42%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_3.csv       |     49.66%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_4.csv       |     49.01%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_5.csv       |     47.97%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_6.csv       |     48.72%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_7.csv       |     43.24%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/ycsb/workloada/qlt_1.csv       |     100.0%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/ycsb/workloada/qlt_2.csv       |     72.22%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/ycsb/workloadc/bclt.csv        |     78.32%    |
# |                                                                          |               |
# |        /content/drive/MyDrive/aaa/datasets/ycsb/workloadc/qlt.csv        |     68.93%    |
# |                                                                          |               |
# +--------------------------------------------------------------------------+---------------+

# %%
feature_name = 'HISTORY' ########################################################
test_ratio_in_percentage = 80 ########################################################
test_ratio = test_ratio_in_percentage / 100 ########################################################
table = PrettyTable()
table.field_names = ["Location", "Average Score"]
for csv_file in all_csv_files_sorted:
    file_path = os.path.join(root_folder, csv_file)
    data = pd.read_csv(file_path)
    data = data.head(int(np.round(len(data) * 0.001)))
    data = data.reset_index()
    test_size = int(np.round(len(data) * test_ratio))
    train_data, test_data = data[:-test_size], data[-test_size:]
    num_columns = train_data.shape[1]
    prediction_indices = range(len(train_data), len(train_data) + test_size)
    prediction_data = pd.DataFrame(prediction_indices, columns=['index'], index=prediction_indices)
    for col in [column for column in train_data.columns if train_data[column].nunique() == 1]:
        prediction_data[col] = pd.Series(train_data[col].iloc[0]).repeat(test_size).values
    columns_not_in_prediction = [col for col in train_data.columns.tolist() if col not in prediction_data.columns.tolist()]
    unique_values_dict = {}
    for col in columns_not_in_prediction:
        unique_values = train_data[col].nunique()
        unique_values_dict[col] = unique_values
    continuous_columns = []
    discrete_columns = []
    for col, unique_values in unique_values_dict.items():
        if unique_values > 500:
            continuous_columns.append(col)
        else:
            discrete_columns.append(col)
    model = CTGAN(verbose=False)
    model.fit(train_data, discrete_columns, epochs=50)
    ctgan_data = model.sample(test_size)
    ctgan_data = ctgan_data.sort_values(by='time', ascending=True)
    num_past_measurements = 20
    start_index = len(data) - test_size
    for col in columns_not_in_prediction:
        for i in range(1, num_past_measurements + 1):
            data[f'{col}_{i}'] = data[col].shift(i * 25)
            if data[f'{col}_{i}'].dtype == 'int64':
                data[f'{col}_{i}'].fillna(-1, inplace=True)
            elif data[f'{col}_{i}'].dtype == 'float64':
                data[f'{col}_{i}'].fillna(-1.0, inplace=True)
            if data[f'{col}_{i}'].dtype != data[col].dtype:
                data[f'{col}_{i}'] = data[f'{col}_{i}'].astype(data[col].dtype)
            train_data.loc[:start_index, f'{col}_{i}'] = data.loc[:start_index, f'{col}_{i}']
            test_data.loc[:start_index, f'{col}_{i}'] = data.loc[:start_index, f'{col}_{i}']
            prediction_data.loc[start_index:, f'{col}_{i}'] = data.loc[start_index:, f'{col}_{i}']
    num_rows = int(np.round(len(train_data) * 0.05))
    for col in columns_not_in_prediction:
        if col in continuous_columns:
            features = [f'{col}_{i}' for i in range(1, num_columns)]
            X_test = prediction_data[features]
            X_train = train_data[features].values[-num_rows:]
            y_train = train_data[col].values[-num_rows:]
            model = LinearRegression()
            model.fit(X_train, y_train)
            y_pred = model.predict(X_test)
            y_pred = np.where(y_pred < -1, -1, y_pred)
            if train_data[col].dtype == np.int64:
                y_pred = np.round(y_pred).astype(np.int64)
            prediction_data[col] = y_pred
    for col in ctgan_data.columns:
        if col not in prediction_data.columns:
            prediction_data[col] = ctgan_data[col].values
    columns_to_drop = ['index']
    if columns_not_in_prediction:
        start_index = train_data.columns.get_loc(f'{columns_not_in_prediction[0]}_1')
        end_index = train_data.columns.get_loc(f'{columns_not_in_prediction[-1]}_{num_past_measurements}')
        columns_to_drop.extend(data.columns[start_index:end_index + 1])
    data = data.drop(columns_to_drop, axis=1)
    train_data = train_data.drop(columns_to_drop, axis=1)
    test_data = test_data.drop(columns_to_drop, axis=1)
    prediction_data = prediction_data.drop(columns_to_drop, axis=1)
    prediction_data = prediction_data[train_data.columns]
    scores = {}
    for col in prediction_data.columns:
        if col in continuous_columns:
            score = r2_score(test_data[col], prediction_data[col])
            if score < 0:
                score = 0
            metric = 'R-squared'
        else:
            score = accuracy_score(test_data[col], prediction_data[col])
            metric = 'Accuracy'
        scores[col] = (score, metric)
    average_score = np.mean([score for score, metric in scores.values()])
    average_score = round(average_score * 100, 2)
    table.add_row([file_path, f'{average_score}%'])
    table.add_row([''] * len(table.field_names))
print(table)
# Out:
# +--------------------------------------------------------------------------+---------------+
# |                                 Location                                 | Average Score |
# +--------------------------------------------------------------------------+---------------+
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/iolt_1.csv   |     77.68%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/iolt_2.csv   |     38.16%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/qlt_1.csv    |     79.91%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/qlt_2.csv    |     80.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/iolt_1.csv   |     81.9%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/iolt_2.csv   |     78.35%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/qlt.csv     |     79.97%    |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/iolt_1.csv      |     77.99%    |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/iolt_2.csv      |     77.83%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/qlt.csv       |     99.98%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/db_bench/mixgraph/iolt.csv      |     54.71%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/db_bench/mixgraph/qlt.csv       |     41.97%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_1/bclt.csv       |     65.28%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_1/qlt.csv        |     60.0%     |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_2/bclt.csv       |     64.14%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_2/qlt.csv        |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/iolt.csv    |     58.35%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/qlt.csv     |     79.03%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_2/qlt.csv     |     59.54%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_3/qlt.csv     |     44.11%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_4/bclt.csv    |     59.64%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_4/iolt.csv    |     51.6%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_4/qlt.csv     |     44.26%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_5/bclt.csv    |     64.88%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_5/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_6/qlt.csv     |     98.87%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_7/qlt.csv     |     78.36%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_8/bclt.csv    |     75.44%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_8/qlt.csv     |     73.82%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_1.csv   |     64.23%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_2.csv   |     61.91%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_3.csv   |     62.05%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_4.csv   |     61.86%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_5.csv   |     61.25%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_6.csv   |     61.44%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_7.csv   |     61.75%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_8.csv   |     60.36%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/iolt.csv    |     60.43%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/qlt.csv     |     79.8%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/bclt.csv     |     67.87%    |
# |                                                                          |               |
# | /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/bclt_replay.csv |     74.94%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/iolt.csv     |     61.15%    |
# |                                                                          |               |
# | /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/iolt_replay.csv |     43.88%    |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/qlt.csv     |     64.04%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/bclt_1.csv    |     53.95%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/bclt_2.csv    |     60.61%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/iolt.csv     |     50.34%    |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/qlt.csv     |     49.3%     |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_3/qlt.csv     |     62.35%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_1/bclt.csv   |     65.69%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_1/qlt.csv    |     40.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_2/bclt.csv   |     65.61%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_2/qlt.csv    |     40.06%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_3/bclt.csv   |     60.66%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_3/qlt.csv    |     53.82%    |
# |                                                                          |               |
# |            /content/drive/MyDrive/aaa/datasets/redis/bclt.csv            |     82.03%    |
# |                                                                          |               |
# |            /content/drive/MyDrive/aaa/datasets/redis/iolt.csv            |     27.39%    |
# |                                                                          |               |
# |            /content/drive/MyDrive/aaa/datasets/redis/qlt.csv             |     80.0%     |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_1.csv       |     60.08%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_2.csv       |     48.36%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_3.csv       |     49.0%     |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_4.csv       |     49.11%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_5.csv       |     48.97%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_6.csv       |     48.83%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_7.csv       |     48.78%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/ycsb/workloada/qlt_1.csv       |     99.33%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/ycsb/workloada/qlt_2.csv       |     73.37%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/ycsb/workloadc/bclt.csv        |     75.23%    |
# |                                                                          |               |
# |        /content/drive/MyDrive/aaa/datasets/ycsb/workloadc/qlt.csv        |     51.83%    |
# |                                                                          |               |
# +--------------------------------------------------------------------------+---------------+
