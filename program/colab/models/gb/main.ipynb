# %%
from google.colab import drive
from natsort import natsorted
from prettytable import PrettyTable
from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.metrics import accuracy_score, r2_score
import numpy as np
import os
import pandas as pd
import warnings
drive.mount('/content/drive')
warnings.filterwarnings('ignore')
root_folder = '/content/drive/MyDrive/aaa/datasets'
def find_and_sort_csv_files(folder):
    csv_files = []
    for root, dirs, files in os.walk(folder):
        for file in files:
            if file.endswith('.csv'):
                csv_files.append(os.path.join(root, file))
    csv_files_sorted = natsorted(csv_files)
    return csv_files_sorted
all_csv_files_sorted = find_and_sort_csv_files(root_folder)
feature_name = 'HISTORY' ########################################################
test_ratio_in_percentage = 20 ########################################################
test_ratio = test_ratio_in_percentage / 100 ########################################################
table = PrettyTable()
table.field_names = ["Location", "Average Score"]
for csv_file in all_csv_files_sorted:
    file_path = os.path.join(root_folder, csv_file)
    data = pd.read_csv(file_path)
    data = data.head(int(np.round(len(data) * 0.001)))
    data = data.reset_index()
    test_size = int(np.round(len(data) * test_ratio))
    train_data, test_data = data[:-test_size], data[-test_size:]
    num_columns = train_data.shape[1]
    prediction_indices = range(len(train_data), len(train_data) + test_size)
    prediction_data = pd.DataFrame(prediction_indices, columns=['index'], index=prediction_indices)
    for col in [column for column in train_data.columns if train_data[column].nunique() == 1]:
        prediction_data[col] = pd.Series(train_data[col].iloc[0]).repeat(test_size).values
    columns_not_in_prediction = [col for col in train_data.columns.tolist() if col not in prediction_data.columns.tolist()]
    unique_values_dict = {}
    for col in columns_not_in_prediction:
        unique_values = train_data[col].nunique()
        unique_values_dict[col] = unique_values
    continuous_columns = []
    discrete_columns = []
    for col, unique_values in unique_values_dict.items():
        if unique_values > 500:
            continuous_columns.append(col)
        else:
            discrete_columns.append(col)
    num_past_measurements = 20
    start_index = len(data) - test_size
    for col in columns_not_in_prediction:
        for i in range(1, num_past_measurements + 1):
            data[f'{col}_{i}'] = data[col].shift(i * 25)
            if data[f'{col}_{i}'].dtype == 'int64':
                data[f'{col}_{i}'].fillna(-1, inplace=True)
            elif data[f'{col}_{i}'].dtype == 'float64':
                data[f'{col}_{i}'].fillna(-1.0, inplace=True)
            if data[f'{col}_{i}'].dtype != data[col].dtype:
                data[f'{col}_{i}'] = data[f'{col}_{i}'].astype(data[col].dtype)
            train_data.loc[:start_index, f'{col}_{i}'] = data.loc[:start_index, f'{col}_{i}']
            test_data.loc[:start_index, f'{col}_{i}'] = data.loc[:start_index, f'{col}_{i}']
            prediction_data.loc[start_index:, f'{col}_{i}'] = data.loc[start_index:, f'{col}_{i}']
    num_rows = int(np.round(len(train_data) * 0.05))
    for col in columns_not_in_prediction:
        features = [f'{col}_{i}' for i in range(1, num_columns)]
        X_test = prediction_data[features]
        if col in continuous_columns:
            X_train = train_data[features].values[-num_rows:]
            y_train = train_data[col].values[-num_rows:]
            model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
        else:
            X_train = train_data[features]
            y_train = train_data[col]
            model = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        y_pred = np.where(y_pred < -1, -1, y_pred)
        if train_data[col].dtype == np.int64:
            y_pred = np.round(y_pred).astype(np.int64)
        prediction_data[col] = y_pred
    columns_to_drop = ['index']
    if columns_not_in_prediction:
        start_index = train_data.columns.get_loc(f'{columns_not_in_prediction[0]}_1')
        end_index = train_data.columns.get_loc(f'{columns_not_in_prediction[-1]}_{num_past_measurements}')
        columns_to_drop.extend(data.columns[start_index:end_index + 1])
    data = data.drop(columns_to_drop, axis=1)
    train_data = train_data.drop(columns_to_drop, axis=1)
    test_data = test_data.drop(columns_to_drop, axis=1)
    prediction_data = prediction_data.drop(columns_to_drop, axis=1)
    prediction_data = prediction_data[train_data.columns]
    scores = {}
    for col in prediction_data.columns:
        if col in continuous_columns:
            score = r2_score(test_data[col], prediction_data[col])
            if score < 0:
                score = 0
            metric = 'R-squared'
        else:
            score = accuracy_score(test_data[col], prediction_data[col])
            metric = 'Accuracy'
        scores[col] = (score, metric)
    average_score = np.mean([score for score, metric in scores.values()])
    average_score = round(average_score * 100, 2)
    table.add_row([file_path, f'{average_score}%'])
    table.add_row([''] * len(table.field_names))
print(table)
# Out:
# Mounted at /content/drive
# +--------------------------------------------------------------------------+---------------+
# |                                 Location                                 | Average Score |
# +--------------------------------------------------------------------------+---------------+
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/iolt_1.csv   |     83.56%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/iolt_2.csv   |     41.91%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/qlt_1.csv    |     60.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/qlt_2.csv    |     60.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/iolt_1.csv   |     85.21%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/iolt_2.csv   |     85.89%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/iolt_1.csv      |     82.9%     |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/iolt_2.csv      |     79.94%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/qlt.csv       |     60.0%     |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/db_bench/mixgraph/iolt.csv      |     68.06%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/db_bench/mixgraph/qlt.csv       |     52.9%     |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_1/bclt.csv       |     61.84%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_1/qlt.csv        |     60.0%     |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_2/bclt.csv       |     62.18%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_2/qlt.csv        |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/iolt.csv    |     50.27%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_2/qlt.csv     |     44.49%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_3/qlt.csv     |     44.65%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_4/bclt.csv    |     55.48%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_4/iolt.csv    |     52.94%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_4/qlt.csv     |     44.23%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_5/bclt.csv    |     62.23%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_5/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_6/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_7/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_8/bclt.csv    |     62.44%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_8/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_1.csv   |     72.22%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_2.csv   |     72.08%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_3.csv   |     71.57%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_4.csv   |     70.9%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_5.csv   |     71.5%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_6.csv   |     72.26%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_7.csv   |     71.41%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_8.csv   |     71.69%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/iolt.csv    |     52.36%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/bclt.csv     |     82.75%    |
# |                                                                          |               |
# | /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/bclt_replay.csv |     72.56%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/iolt.csv     |     61.24%    |
# |                                                                          |               |
# | /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/iolt_replay.csv |     51.2%     |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/bclt_1.csv    |     57.14%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/bclt_2.csv    |     62.61%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/iolt.csv     |     51.6%     |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_3/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_1/bclt.csv   |     62.52%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_1/qlt.csv    |     40.62%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_2/bclt.csv   |     62.79%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_2/qlt.csv    |     41.06%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_3/bclt.csv   |     62.33%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_3/qlt.csv    |     40.72%    |
# |                                                                          |               |
# |            /content/drive/MyDrive/aaa/datasets/redis/bclt.csv            |     83.67%    |
# |                                                                          |               |
# |            /content/drive/MyDrive/aaa/datasets/redis/iolt.csv            |     41.67%    |
# |                                                                          |               |
# |            /content/drive/MyDrive/aaa/datasets/redis/qlt.csv             |     80.0%     |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_1.csv       |     59.87%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_2.csv       |     54.11%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_3.csv       |     54.04%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_4.csv       |     53.11%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_5.csv       |     53.6%     |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_6.csv       |     54.43%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_7.csv       |     53.58%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/ycsb/workloada/qlt_1.csv       |     80.0%     |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/ycsb/workloada/qlt_2.csv       |     67.26%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/ycsb/workloadc/bclt.csv        |     89.87%    |
# |                                                                          |               |
# |        /content/drive/MyDrive/aaa/datasets/ycsb/workloadc/qlt.csv        |     74.13%    |
# |                                                                          |               |
# +--------------------------------------------------------------------------+---------------+

# %%
feature_name = 'HISTORY' ########################################################
test_ratio_in_percentage = 50 ########################################################
test_ratio = test_ratio_in_percentage / 100 ########################################################
table = PrettyTable()
table.field_names = ["Location", "Average Score"]
for csv_file in all_csv_files_sorted:
    file_path = os.path.join(root_folder, csv_file)
    data = pd.read_csv(file_path)
    data = data.head(int(np.round(len(data) * 0.001)))
    data = data.reset_index()
    test_size = int(np.round(len(data) * test_ratio))
    train_data, test_data = data[:-test_size], data[-test_size:]
    num_columns = train_data.shape[1]
    prediction_indices = range(len(train_data), len(train_data) + test_size)
    prediction_data = pd.DataFrame(prediction_indices, columns=['index'], index=prediction_indices)
    for col in [column for column in train_data.columns if train_data[column].nunique() == 1]:
        prediction_data[col] = pd.Series(train_data[col].iloc[0]).repeat(test_size).values
    columns_not_in_prediction = [col for col in train_data.columns.tolist() if col not in prediction_data.columns.tolist()]
    unique_values_dict = {}
    for col in columns_not_in_prediction:
        unique_values = train_data[col].nunique()
        unique_values_dict[col] = unique_values
    continuous_columns = []
    discrete_columns = []
    for col, unique_values in unique_values_dict.items():
        if unique_values > 500:
            continuous_columns.append(col)
        else:
            discrete_columns.append(col)
    num_past_measurements = 20
    start_index = len(data) - test_size
    for col in columns_not_in_prediction:
        for i in range(1, num_past_measurements + 1):
            data[f'{col}_{i}'] = data[col].shift(i * 25)
            if data[f'{col}_{i}'].dtype == 'int64':
                data[f'{col}_{i}'].fillna(-1, inplace=True)
            elif data[f'{col}_{i}'].dtype == 'float64':
                data[f'{col}_{i}'].fillna(-1.0, inplace=True)
            if data[f'{col}_{i}'].dtype != data[col].dtype:
                data[f'{col}_{i}'] = data[f'{col}_{i}'].astype(data[col].dtype)
            train_data.loc[:start_index, f'{col}_{i}'] = data.loc[:start_index, f'{col}_{i}']
            test_data.loc[:start_index, f'{col}_{i}'] = data.loc[:start_index, f'{col}_{i}']
            prediction_data.loc[start_index:, f'{col}_{i}'] = data.loc[start_index:, f'{col}_{i}']
    num_rows = int(np.round(len(train_data) * 0.05))
    for col in columns_not_in_prediction:
        features = [f'{col}_{i}' for i in range(1, num_columns)]
        X_test = prediction_data[features]
        if col in continuous_columns:
            X_train = train_data[features].values[-num_rows:]
            y_train = train_data[col].values[-num_rows:]
            model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
        else:
            X_train = train_data[features]
            y_train = train_data[col]
            model = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        y_pred = np.where(y_pred < -1, -1, y_pred)
        if train_data[col].dtype == np.int64:
            y_pred = np.round(y_pred).astype(np.int64)
        prediction_data[col] = y_pred
    columns_to_drop = ['index']
    if columns_not_in_prediction:
        start_index = train_data.columns.get_loc(f'{columns_not_in_prediction[0]}_1')
        end_index = train_data.columns.get_loc(f'{columns_not_in_prediction[-1]}_{num_past_measurements}')
        columns_to_drop.extend(data.columns[start_index:end_index + 1])
    data = data.drop(columns_to_drop, axis=1)
    train_data = train_data.drop(columns_to_drop, axis=1)
    test_data = test_data.drop(columns_to_drop, axis=1)
    prediction_data = prediction_data.drop(columns_to_drop, axis=1)
    prediction_data = prediction_data[train_data.columns]
    scores = {}
    for col in prediction_data.columns:
        if col in continuous_columns:
            score = r2_score(test_data[col], prediction_data[col])
            if score < 0:
                score = 0
            metric = 'R-squared'
        else:
            score = accuracy_score(test_data[col], prediction_data[col])
            metric = 'Accuracy'
        scores[col] = (score, metric)
    average_score = np.mean([score for score, metric in scores.values()])
    average_score = round(average_score * 100, 2)
    table.add_row([file_path, f'{average_score}%'])
    table.add_row([''] * len(table.field_names))
print(table)
# Out:
# +--------------------------------------------------------------------------+---------------+
# |                                 Location                                 | Average Score |
# +--------------------------------------------------------------------------+---------------+
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/iolt_1.csv   |     82.01%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/iolt_2.csv   |     41.32%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/qlt_1.csv    |     60.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/qlt_2.csv    |     60.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/iolt_1.csv   |     74.69%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/iolt_2.csv   |     86.09%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/iolt_1.csv      |     82.3%     |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/iolt_2.csv      |     77.94%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/qlt.csv       |     60.0%     |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/db_bench/mixgraph/iolt.csv      |     68.41%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/db_bench/mixgraph/qlt.csv       |     52.96%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_1/bclt.csv       |     61.48%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_1/qlt.csv        |     60.0%     |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_2/bclt.csv       |     61.98%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_2/qlt.csv        |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/iolt.csv    |     50.08%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_2/qlt.csv     |     43.85%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_3/qlt.csv     |     43.82%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_4/bclt.csv    |     56.88%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_4/iolt.csv    |     52.35%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_4/qlt.csv     |     43.49%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_5/bclt.csv    |     61.88%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_5/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_6/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_7/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_8/bclt.csv    |     62.35%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_8/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_1.csv   |     71.82%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_2.csv   |     70.97%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_3.csv   |     71.21%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_4.csv   |     71.05%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_5.csv   |     71.32%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_6.csv   |     71.6%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_7.csv   |     71.18%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_8.csv   |     71.3%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/iolt.csv    |     52.22%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/bclt.csv     |     81.38%    |
# |                                                                          |               |
# | /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/bclt_replay.csv |     72.36%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/iolt.csv     |     61.37%    |
# |                                                                          |               |
# | /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/iolt_replay.csv |     51.02%    |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/bclt_1.csv    |     55.36%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/bclt_2.csv    |     62.83%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/iolt.csv     |     51.6%     |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_3/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_1/bclt.csv   |     62.1%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_1/qlt.csv    |     38.82%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_2/bclt.csv   |     62.36%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_2/qlt.csv    |     39.65%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_3/bclt.csv   |     59.62%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_3/qlt.csv    |     40.98%    |
# |                                                                          |               |
# |            /content/drive/MyDrive/aaa/datasets/redis/bclt.csv            |     83.71%    |
# |                                                                          |               |
# |            /content/drive/MyDrive/aaa/datasets/redis/iolt.csv            |     40.27%    |
# |                                                                          |               |
# |            /content/drive/MyDrive/aaa/datasets/redis/qlt.csv             |     80.0%     |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_1.csv       |     59.02%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_2.csv       |     53.73%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_3.csv       |     53.68%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_4.csv       |     52.93%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_5.csv       |     53.24%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_6.csv       |     54.42%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_7.csv       |     53.17%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/ycsb/workloada/qlt_1.csv       |     80.0%     |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/ycsb/workloada/qlt_2.csv       |     67.9%     |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/ycsb/workloadc/bclt.csv        |     89.67%    |
# |                                                                          |               |
# |        /content/drive/MyDrive/aaa/datasets/ycsb/workloadc/qlt.csv        |     74.12%    |
# |                                                                          |               |
# +--------------------------------------------------------------------------+---------------+

# %%
from google.colab import drive
from natsort import natsorted
from prettytable import PrettyTable
from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.metrics import accuracy_score, r2_score
import numpy as np
import os
import pandas as pd
import warnings
drive.mount('/content/drive')
warnings.filterwarnings('ignore')
root_folder = '/content/drive/MyDrive/aaa/datasets'
def find_and_sort_csv_files(folder):
    csv_files = []
    for root, dirs, files in os.walk(folder):
        for file in files:
            if file.endswith('.csv'):
                csv_files.append(os.path.join(root, file))
    csv_files_sorted = natsorted(csv_files)
    return csv_files_sorted
all_csv_files_sorted = find_and_sort_csv_files(root_folder)
feature_name = 'HISTORY' ########################################################
test_ratio_in_percentage = 80 ########################################################
test_ratio = test_ratio_in_percentage / 100 ########################################################
table = PrettyTable()
table.field_names = ["Location", "Average Score"]
for csv_file in all_csv_files_sorted:
    file_path = os.path.join(root_folder, csv_file)
    data = pd.read_csv(file_path)
    data = data.head(int(np.round(len(data) * 0.001)))
    data = data.reset_index()
    test_size = int(np.round(len(data) * test_ratio))
    train_data, test_data = data[:-test_size], data[-test_size:]
    num_columns = train_data.shape[1]
    prediction_indices = range(len(train_data), len(train_data) + test_size)
    prediction_data = pd.DataFrame(prediction_indices, columns=['index'], index=prediction_indices)
    for col in [column for column in train_data.columns if train_data[column].nunique() == 1]:
        prediction_data[col] = pd.Series(train_data[col].iloc[0]).repeat(test_size).values
    columns_not_in_prediction = [col for col in train_data.columns.tolist() if col not in prediction_data.columns.tolist()]
    unique_values_dict = {}
    for col in columns_not_in_prediction:
        unique_values = train_data[col].nunique()
        unique_values_dict[col] = unique_values
    continuous_columns = []
    discrete_columns = []
    for col, unique_values in unique_values_dict.items():
        if unique_values > 500:
            continuous_columns.append(col)
        else:
            discrete_columns.append(col)
    num_past_measurements = 20
    start_index = len(data) - test_size
    for col in columns_not_in_prediction:
        for i in range(1, num_past_measurements + 1):
            data[f'{col}_{i}'] = data[col].shift(i * 25)
            if data[f'{col}_{i}'].dtype == 'int64':
                data[f'{col}_{i}'].fillna(-1, inplace=True)
            elif data[f'{col}_{i}'].dtype == 'float64':
                data[f'{col}_{i}'].fillna(-1.0, inplace=True)
            if data[f'{col}_{i}'].dtype != data[col].dtype:
                data[f'{col}_{i}'] = data[f'{col}_{i}'].astype(data[col].dtype)
            train_data.loc[:start_index, f'{col}_{i}'] = data.loc[:start_index, f'{col}_{i}']
            test_data.loc[:start_index, f'{col}_{i}'] = data.loc[:start_index, f'{col}_{i}']
            prediction_data.loc[start_index:, f'{col}_{i}'] = data.loc[start_index:, f'{col}_{i}']
    num_rows = int(np.round(len(train_data) * 0.05))
    for col in columns_not_in_prediction:
        features = [f'{col}_{i}' for i in range(1, num_columns)]
        X_test = prediction_data[features]
        if col in continuous_columns:
            X_train = train_data[features].values[-num_rows:]
            y_train = train_data[col].values[-num_rows:]
            model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
        else:
            X_train = train_data[features]
            y_train = train_data[col]
            model = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        y_pred = np.where(y_pred < -1, -1, y_pred)
        if train_data[col].dtype == np.int64:
            y_pred = np.round(y_pred).astype(np.int64)
        prediction_data[col] = y_pred
    columns_to_drop = ['index']
    if columns_not_in_prediction:
        start_index = train_data.columns.get_loc(f'{columns_not_in_prediction[0]}_1')
        end_index = train_data.columns.get_loc(f'{columns_not_in_prediction[-1]}_{num_past_measurements}')
        columns_to_drop.extend(data.columns[start_index:end_index + 1])
    data = data.drop(columns_to_drop, axis=1)
    train_data = train_data.drop(columns_to_drop, axis=1)
    test_data = test_data.drop(columns_to_drop, axis=1)
    prediction_data = prediction_data.drop(columns_to_drop, axis=1)
    prediction_data = prediction_data[train_data.columns]
    scores = {}
    for col in prediction_data.columns:
        if col in continuous_columns:
            score = r2_score(test_data[col], prediction_data[col])
            if score < 0:
                score = 0
            metric = 'R-squared'
        else:
            score = accuracy_score(test_data[col], prediction_data[col])
            metric = 'Accuracy'
        scores[col] = (score, metric)
    average_score = np.mean([score for score, metric in scores.values()])
    average_score = round(average_score * 100, 2)
    table.add_row([file_path, f'{average_score}%'])
    table.add_row([''] * len(table.field_names))
print(table)
# Out:
# Mounted at /content/drive
# +--------------------------------------------------------------------------+---------------+
# |                                 Location                                 | Average Score |
# +--------------------------------------------------------------------------+---------------+
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/iolt_1.csv   |     67.63%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/iolt_2.csv   |     50.15%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/qlt_1.csv    |     60.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/qlt_2.csv    |     60.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/iolt_1.csv   |     74.07%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/iolt_2.csv   |     77.81%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/iolt_1.csv      |     69.37%    |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/iolt_2.csv      |     79.8%     |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/qlt.csv       |     60.0%     |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/db_bench/mixgraph/iolt.csv      |     69.16%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/db_bench/mixgraph/qlt.csv       |     52.82%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_1/bclt.csv       |     61.78%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_1/qlt.csv        |     60.0%     |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_2/bclt.csv       |     61.57%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_2/qlt.csv        |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/iolt.csv    |     49.65%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_2/qlt.csv     |     43.63%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_3/qlt.csv     |     43.88%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_4/bclt.csv    |     57.32%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_4/iolt.csv    |     52.74%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_4/qlt.csv     |     43.95%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_5/bclt.csv    |     61.46%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_5/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_6/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_7/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_8/bclt.csv    |     62.19%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_8/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_1.csv   |     65.92%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_2.csv   |     66.05%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_3.csv   |     65.46%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_4.csv   |     66.15%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_5.csv   |     65.83%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_6.csv   |     66.3%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_7.csv   |     65.97%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_8.csv   |     66.26%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/iolt.csv    |     52.04%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/bclt.csv     |     64.65%    |
# |                                                                          |               |
# | /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/bclt_replay.csv |     72.17%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/iolt.csv     |     61.14%    |
# |                                                                          |               |
# | /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/iolt_replay.csv |     51.4%     |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/bclt_1.csv    |     53.7%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/bclt_2.csv    |     61.46%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/iolt.csv     |     52.79%    |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_3/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_1/bclt.csv   |     61.86%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_1/qlt.csv    |     39.43%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_2/bclt.csv   |     61.83%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_2/qlt.csv    |     40.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_3/bclt.csv   |     59.22%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_3/qlt.csv    |     40.52%    |
# |                                                                          |               |
# |            /content/drive/MyDrive/aaa/datasets/redis/bclt.csv            |     82.39%    |
# |                                                                          |               |
# |            /content/drive/MyDrive/aaa/datasets/redis/iolt.csv            |     39.66%    |
# |                                                                          |               |
# |            /content/drive/MyDrive/aaa/datasets/redis/qlt.csv             |     80.0%     |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_1.csv       |     61.73%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_2.csv       |     52.99%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_3.csv       |     53.1%     |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_4.csv       |     52.01%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_5.csv       |     52.22%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_6.csv       |     53.53%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_7.csv       |     52.41%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/ycsb/workloada/qlt_1.csv       |     80.0%     |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/ycsb/workloada/qlt_2.csv       |     67.73%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/ycsb/workloadc/bclt.csv        |     70.49%    |
# |                                                                          |               |
# |        /content/drive/MyDrive/aaa/datasets/ycsb/workloadc/qlt.csv        |     54.22%    |
# |                                                                          |               |
# +--------------------------------------------------------------------------+---------------+
