# %%
from google.colab import drive
from keras.layers import Conv1D, Dense, Flatten
from keras.models import Sequential
from natsort import natsorted
from prettytable import PrettyTable
from sklearn.metrics import accuracy_score, r2_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import numpy as np
import os
import pandas as pd
import warnings
drive.mount('/content/drive')
warnings.filterwarnings('ignore')
root_folder = '/content/drive/MyDrive/aaa/datasets'
def find_and_sort_csv_files(folder):
    csv_files = []
    for root, dirs, files in os.walk(folder):
        for file in files:
            if file.endswith('.csv'):
                csv_files.append(os.path.join(root, file))
    csv_files_sorted = natsorted(csv_files)
    return csv_files_sorted
all_csv_files_sorted = find_and_sort_csv_files(root_folder)
feature_name = 'HISTORY' ########################################################
test_ratio_in_percentage = 20 ########################################################
test_ratio = test_ratio_in_percentage / 100 ########################################################
table = PrettyTable()
table.field_names = ["Location", "Average Score"]
for csv_file in all_csv_files_sorted:
    file_path = os.path.join(root_folder, csv_file)
    data = pd.read_csv(file_path)
    data = data.head(int(np.round(len(data) * 0.001)))
    data = data.reset_index()
    test_size = int(np.round(len(data) * test_ratio))
    train_data, test_data = data[:-test_size], data[-test_size:]
    num_columns = train_data.shape[1]
    prediction_indices = range(len(train_data), len(train_data) + test_size)
    prediction_data = pd.DataFrame(prediction_indices, columns=['index'], index=prediction_indices)
    for col in [column for column in train_data.columns if train_data[column].nunique() == 1]:
        prediction_data[col] = pd.Series(train_data[col].iloc[0]).repeat(test_size).values
    columns_not_in_prediction = [col for col in train_data.columns.tolist() if col not in prediction_data.columns.tolist()]
    unique_values_dict = {}
    for col in columns_not_in_prediction:
        unique_values = train_data[col].nunique()
        unique_values_dict[col] = unique_values
    continuous_columns = []
    discrete_columns = []
    for col, unique_values in unique_values_dict.items():
        if unique_values > 500:
            continuous_columns.append(col)
        else:
            discrete_columns.append(col)
    num_past_measurements = 20
    start_index = len(data) - test_size
    for col in columns_not_in_prediction:
        for i in range(1, num_past_measurements + 1):
            data[f'{col}_{i}'] = data[col].shift(i * 25)
            if data[f'{col}_{i}'].dtype == 'int64':
                data[f'{col}_{i}'].fillna(-1, inplace=True)
            elif data[f'{col}_{i}'].dtype == 'float64':
                data[f'{col}_{i}'].fillna(-1.0, inplace=True)
            if data[f'{col}_{i}'].dtype != data[col].dtype:
                data[f'{col}_{i}'] = data[f'{col}_{i}'].astype(data[col].dtype)
            train_data.loc[:start_index, f'{col}_{i}'] = data.loc[:start_index, f'{col}_{i}']
            test_data.loc[:start_index, f'{col}_{i}'] = data.loc[:start_index, f'{col}_{i}']
            prediction_data.loc[start_index:, f'{col}_{i}'] = data.loc[start_index:, f'{col}_{i}']
    num_rows = int(np.round(len(train_data) * 0.05))
    scaler = StandardScaler()
    y_scaler = MinMaxScaler()
    for col in columns_not_in_prediction:
        features = [f'{col}_{i}' for i in range(1, num_columns)]
        X_test = prediction_data[features]
        if col in continuous_columns:
            X_train = train_data[features].values[-num_rows:]
            y_train = train_data[col].values[-num_rows:]
        else:
            X_train = train_data[features].values
            y_train = train_data[col].values
        min_value = y_train.min()
        y_train -= min_value
        y_train_scaled = y_scaler.fit_transform(y_train.reshape(-1, 1))
        X_train_scaled = scaler.fit_transform(X_train)
        X_test_scaled = scaler.transform(X_test)
        X_train_scaled = X_train_scaled.reshape((X_train_scaled.shape[0], X_train_scaled.shape[1], 1))
        X_test_scaled = X_test_scaled.reshape((X_test_scaled.shape[0], X_test_scaled.shape[1], 1))
        model = Sequential()
        model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train_scaled.shape[1], 1)))
        model.add(Flatten())
        if col in continuous_columns:
            model.add(Dense(1, activation='linear'))
            model.compile(loss='mean_squared_error', optimizer='adam')
        else:
            model.add(Dense(len(np.unique(y_train_scaled)), activation='softmax'))
            model.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'], optimizer='adam')
        model.fit(X_train_scaled, y_train_scaled, epochs=10, batch_size=128, verbose=0)
        y_pred_scaled = model.predict(X_test_scaled)
        if col in continuous_columns:
            y_pred = y_scaler.inverse_transform(y_pred_scaled.reshape(-1, 1))
        else:
            y_pred = y_pred_scaled
            y_pred = np.argmax(y_pred, axis=1)
        y_pred += min_value
        y_pred = np.where(y_pred < -1, -1, y_pred)
        if train_data[col].dtype == np.int64:
            y_pred = np.round(y_pred).astype(np.int64)
        prediction_data[col] = y_pred
    columns_to_drop = ['index']
    if columns_not_in_prediction:
        start_index = train_data.columns.get_loc(f'{columns_not_in_prediction[0]}_1')
        end_index = train_data.columns.get_loc(f'{columns_not_in_prediction[-1]}_{num_past_measurements}')
        columns_to_drop.extend(data.columns[start_index:end_index + 1])
    data = data.drop(columns_to_drop, axis=1)
    train_data = train_data.drop(columns_to_drop, axis=1)
    test_data = test_data.drop(columns_to_drop, axis=1)
    prediction_data = prediction_data.drop(columns_to_drop, axis=1)
    prediction_data = prediction_data[train_data.columns]
    scores = {}
    for col in prediction_data.columns:
        if col in continuous_columns:
            score = r2_score(test_data[col], prediction_data[col])
            if score < 0:
                score = 0
            metric = 'R-squared'
        else:
            score = accuracy_score(test_data[col], prediction_data[col])
            metric = 'Accuracy'
        scores[col] = (score, metric)
    average_score = np.mean([score for score, metric in scores.values()])
    average_score = round(average_score * 100, 2)
    table.add_row([file_path, f'{average_score}%'])
    table.add_row([''] * len(table.field_names))
print(table)
# Out:
# Mounted at /content/drive
# 107/107 [==============================] - 0s 1ms/step
# 107/107 [==============================] - 0s 2ms/step
# 107/107 [==============================] - 0s 1ms/step
# 107/107 [==============================] - 0s 1ms/step
# 107/107 [==============================] - 0s 1ms/step
# 107/107 [==============================] - 0s 1ms/step
# 107/107 [==============================] - 0s 1ms/step
# 107/107 [==============================] - 0s 1ms/step
# 107/107 [==============================] - 0s 1ms/step
# 107/107 [==============================] - 0s 1ms/step
# 107/107 [==============================] - 0s 1ms/step
# 107/107 [==============================] - 0s 1ms/step
# 107/107 [==============================] - 0s 1ms/step
# 94/94 [==============================] - 0s 1ms/step
# 94/94 [==============================] - 0s 1ms/step
# 94/94 [==============================] - 0s 1ms/step
# 94/94 [==============================] - 0s 1ms/step
# 126/126 [==============================] - 0s 1ms/step
# 126/126 [==============================] - 0s 1ms/step
# 126/126 [==============================] - 0s 1ms/step
# 126/126 [==============================] - 0s 1ms/step
# 126/126 [==============================] - 0s 1ms/step
# 126/126 [==============================] - 0s 1ms/step
# 126/126 [==============================] - 0s 1ms/step
# 126/126 [==============================] - 0s 1ms/step
# 126/126 [==============================] - 0s 1ms/step
# 126/126 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# WARNING:tensorflow:5 out of the last 132 calls to <function Model.make_predict_function.<locals>.predict_function at 0x797f46aae320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 4ms/step
# WARNING:tensorflow:6 out of the last 134 calls to <function Model.make_predict_function.<locals>.predict_function at 0x797f46aac790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 4ms/step
# 7/7 [==============================] - 0s 3ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 1ms/step
# 12/12 [==============================] - 0s 3ms/step
# 12/12 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 31/31 [==============================] - 0s 2ms/step
# 31/31 [==============================] - 0s 1ms/step
# 31/31 [==============================] - 0s 1ms/step
# 31/31 [==============================] - 0s 1ms/step
# 31/31 [==============================] - 0s 1ms/step
# 17/17 [==============================] - 0s 1ms/step
# 17/17 [==============================] - 0s 1ms/step
# 18/18 [==============================] - 0s 2ms/step
# 18/18 [==============================] - 0s 2ms/step
# 18/18 [==============================] - 0s 1ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 1ms/step
# 13/13 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 1ms/step
# 12/12 [==============================] - 0s 2ms/step
# 12/12 [==============================] - 0s 2ms/step
# 12/12 [==============================] - 0s 2ms/step
# 12/12 [==============================] - 0s 2ms/step
# 12/12 [==============================] - 0s 2ms/step
# 12/12 [==============================] - 0s 2ms/step
# 12/12 [==============================] - 0s 2ms/step
# 12/12 [==============================] - 0s 1ms/step
# 31/31 [==============================] - 0s 1ms/step
# 31/31 [==============================] - 0s 1ms/step
# 31/31 [==============================] - 0s 1ms/step
# 31/31 [==============================] - 0s 1ms/step
# 31/31 [==============================] - 0s 1ms/step
# 31/31 [==============================] - 0s 1ms/step
# 31/31 [==============================] - 0s 1ms/step
# 31/31 [==============================] - 0s 1ms/step
# 31/31 [==============================] - 0s 1ms/step
# 31/31 [==============================] - 0s 1ms/step
# 31/31 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 0s 1ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 34/34 [==============================] - 0s 2ms/step
# 34/34 [==============================] - 0s 2ms/step
# 34/34 [==============================] - 0s 1ms/step
# 34/34 [==============================] - 0s 1ms/step
# 34/34 [==============================] - 0s 1ms/step
# 34/34 [==============================] - 0s 1ms/step
# 34/34 [==============================] - 0s 1ms/step
# 34/34 [==============================] - 0s 1ms/step
# 34/34 [==============================] - 0s 1ms/step
# 34/34 [==============================] - 0s 2ms/step
# 34/34 [==============================] - 0s 1ms/step
# 17/17 [==============================] - 0s 1ms/step
# 17/17 [==============================] - 0s 2ms/step
# 66/66 [==============================] - 0s 2ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 2ms/step
# 66/66 [==============================] - 0s 2ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 2ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 2ms/step
# 66/66 [==============================] - 0s 2ms/step
# 66/66 [==============================] - 0s 2ms/step
# 66/66 [==============================] - 0s 2ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step
# 54/54 [==============================] - 0s 2ms/step
# 54/54 [==============================] - 0s 1ms/step
# 54/54 [==============================] - 0s 1ms/step
# 54/54 [==============================] - 0s 1ms/step
# 54/54 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 0s 1ms/step
# 29/29 [==============================] - 0s 2ms/step
# 29/29 [==============================] - 0s 1ms/step
# 29/29 [==============================] - 0s 1ms/step
# 29/29 [==============================] - 0s 1ms/step
# 29/29 [==============================] - 0s 1ms/step
# 29/29 [==============================] - 0s 1ms/step
# 29/29 [==============================] - 0s 1ms/step
# 29/29 [==============================] - 0s 1ms/step
# 29/29 [==============================] - 0s 1ms/step
# 29/29 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 2ms/step
# 27/27 [==============================] - 0s 2ms/step
# 27/27 [==============================] - 0s 1ms/step
# 14/14 [==============================] - 0s 2ms/step
# 14/14 [==============================] - 0s 2ms/step
# 14/14 [==============================] - 0s 2ms/step
# 14/14 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 2ms/step
# 27/27 [==============================] - 0s 2ms/step
# 27/27 [==============================] - 0s 2ms/step
# 19/19 [==============================] - 0s 2ms/step
# 19/19 [==============================] - 0s 2ms/step
# 19/19 [==============================] - 0s 2ms/step
# 19/19 [==============================] - 0s 2ms/step
# 41/41 [==============================] - 0s 2ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 2ms/step
# 41/41 [==============================] - 0s 2ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 2ms/step
# 41/41 [==============================] - 0s 2ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 1ms/step
# 41/41 [==============================] - 0s 1ms/step
# 7/7 [==============================] - 0s 3ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 14/14 [==============================] - 0s 2ms/step
# 14/14 [==============================] - 0s 1ms/step
# 14/14 [==============================] - 0s 2ms/step
# 14/14 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 1ms/step
# 21/21 [==============================] - 0s 1ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 1ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 1ms/step
# 21/21 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 1ms/step
# 21/21 [==============================] - 0s 1ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 30/30 [==============================] - 0s 2ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 2ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 2ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 17/17 [==============================] - 0s 1ms/step
# 17/17 [==============================] - 0s 1ms/step
# 17/17 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 1ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 2s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 2s 2ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 1ms/step
# 101/101 [==============================] - 0s 1ms/step
# 101/101 [==============================] - 0s 1ms/step
# 101/101 [==============================] - 0s 1ms/step
# 101/101 [==============================] - 0s 1ms/step
# 101/101 [==============================] - 0s 1ms/step
# 101/101 [==============================] - 0s 1ms/step
# 101/101 [==============================] - 0s 1ms/step
# 20/20 [==============================] - 0s 2ms/step
# 20/20 [==============================] - 0s 1ms/step
# 20/20 [==============================] - 0s 2ms/step
# 20/20 [==============================] - 0s 2ms/step
# 20/20 [==============================] - 0s 1ms/step
# 20/20 [==============================] - 0s 2ms/step
# 20/20 [==============================] - 0s 2ms/step
# 20/20 [==============================] - 0s 1ms/step
# 20/20 [==============================] - 0s 2ms/step
# 20/20 [==============================] - 0s 2ms/step
# 20/20 [==============================] - 0s 2ms/step
# 20/20 [==============================] - 0s 2ms/step
# 119/119 [==============================] - 0s 1ms/step
# 119/119 [==============================] - 0s 1ms/step
# 119/119 [==============================] - 0s 1ms/step
# 119/119 [==============================] - 0s 1ms/step
# 119/119 [==============================] - 0s 1ms/step
# +---------------------------------------------------------------------------------------+---------------+
# |                                        Location                                       | Average Score |
# +---------------------------------------------------------------------------------------+---------------+
# |          /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/iolt_1.csv         |     80.83%    |
# |                                                                                       |               |
# |          /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/iolt_2.csv         |     27.16%    |
# |                                                                                       |               |
# |          /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/qlt_1.csv          |     60.0%     |
# |                                                                                       |               |
# |          /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/qlt_2.csv          |     60.0%     |
# |                                                                                       |               |
# |          /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/iolt_1.csv         |     80.38%    |
# |                                                                                       |               |
# |          /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/iolt_2.csv         |     85.82%    |
# |                                                                                       |               |
# |           /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/qlt.csv           |     60.0%     |
# |                                                                                       |               |
# |            /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/iolt_1.csv            |     81.23%    |
# |                                                                                       |               |
# |            /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/iolt_2.csv            |     72.22%    |
# |                                                                                       |               |
# |              /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/qlt.csv             |     60.0%     |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/db_bench/mixgraph/iolt.csv            |     67.06%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/db_bench/mixgraph/qlt.csv             |     54.1%     |
# |                                                                                       |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/read_1/bclt.csv       |     58.0%     |
# |                                                                                       |               |
# |        /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/read_1/qlt.csv       |     60.0%     |
# |                                                                                       |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/read_2/bclt.csv       |     60.25%    |
# |                                                                                       |               |
# |        /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/read_2/qlt.csv       |     60.0%     |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_1/iolt.csv    |     50.29%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_1/qlt.csv    |     60.0%     |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_2/qlt.csv    |     43.85%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_3/qlt.csv    |     44.01%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_4/bclt.csv    |     50.15%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_4/iolt.csv    |     51.88%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_4/qlt.csv    |     43.61%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_5/bclt.csv    |     58.88%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_5/qlt.csv    |     60.0%     |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_6/qlt.csv    |     60.0%     |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_7/qlt.csv    |     60.0%     |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_8/bclt.csv    |     58.77%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_8/qlt.csv    |     60.0%     |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_1.csv   |     67.03%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_2.csv   |     65.36%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_3.csv   |     65.25%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_4.csv   |     64.92%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_5.csv   |     64.74%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_6.csv   |     65.95%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_7.csv   |     65.22%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_8.csv   |     65.5%     |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/iolt.csv    |     48.39%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/qlt.csv    |     60.0%     |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_1/bclt.csv    |     75.0%     |
# |                                                                                       |               |
# | /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_1/bclt_replay.csv |     67.73%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_1/iolt.csv    |     60.99%    |
# |                                                                                       |               |
# | /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_1/iolt_replay.csv |     45.48%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_1/qlt.csv     |     57.96%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_2/bclt_1.csv   |     49.87%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_2/bclt_2.csv   |     49.65%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_2/iolt.csv    |     50.85%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_2/qlt.csv     |     58.0%     |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_3/qlt.csv     |     58.0%     |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/updaterandom_1/bclt.csv   |     59.11%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/updaterandom_1/qlt.csv   |     34.73%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/updaterandom_2/bclt.csv   |     59.54%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/updaterandom_2/qlt.csv   |     35.48%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/updaterandom_3/bclt.csv   |     60.0%     |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/updaterandom_3/qlt.csv   |     36.27%    |
# |                                                                                       |               |
# |                   /content/drive/MyDrive/aaa/datasets/redis/bclt.csv                  |     80.0%     |
# |                                                                                       |               |
# |                   /content/drive/MyDrive/aaa/datasets/redis/iolt.csv                  |     26.01%    |
# |                                                                                       |               |
# |                   /content/drive/MyDrive/aaa/datasets/redis/qlt.csv                   |     80.0%     |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_1.csv             |     49.31%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_2.csv             |     44.02%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_3.csv             |     42.73%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_4.csv             |     42.22%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_5.csv             |     43.13%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_6.csv             |     45.12%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_7.csv             |     44.78%    |
# |                                                                                       |               |
# |              /content/drive/MyDrive/aaa/datasets/ycsb/workloada/qlt_1.csv             |     80.0%     |
# |                                                                                       |               |
# |              /content/drive/MyDrive/aaa/datasets/ycsb/workloada/qlt_2.csv             |     61.28%    |
# |                                                                                       |               |
# |              /content/drive/MyDrive/aaa/datasets/ycsb/workloadc/bclt.csv              |     79.89%    |
# |                                                                                       |               |
# |               /content/drive/MyDrive/aaa/datasets/ycsb/workloadc/qlt.csv              |     55.3%     |
# |                                                                                       |               |
# +---------------------------------------------------------------------------------------+---------------+

# %%
feature_name = 'HISTORY' ########################################################
test_ratio_in_percentage = 50 ########################################################
test_ratio = test_ratio_in_percentage / 100 ########################################################
table = PrettyTable()
table.field_names = ["Location", "Average Score"]
for csv_file in all_csv_files_sorted:
    file_path = os.path.join(root_folder, csv_file)
    data = pd.read_csv(file_path)
    data = data.head(int(np.round(len(data) * 0.001)))
    data = data.reset_index()
    test_size = int(np.round(len(data) * test_ratio))
    train_data, test_data = data[:-test_size], data[-test_size:]
    num_columns = train_data.shape[1]
    prediction_indices = range(len(train_data), len(train_data) + test_size)
    prediction_data = pd.DataFrame(prediction_indices, columns=['index'], index=prediction_indices)
    for col in [column for column in train_data.columns if train_data[column].nunique() == 1]:
        prediction_data[col] = pd.Series(train_data[col].iloc[0]).repeat(test_size).values
    columns_not_in_prediction = [col for col in train_data.columns.tolist() if col not in prediction_data.columns.tolist()]
    unique_values_dict = {}
    for col in columns_not_in_prediction:
        unique_values = train_data[col].nunique()
        unique_values_dict[col] = unique_values
    continuous_columns = []
    discrete_columns = []
    for col, unique_values in unique_values_dict.items():
        if unique_values > 500:
            continuous_columns.append(col)
        else:
            discrete_columns.append(col)
    num_past_measurements = 20
    start_index = len(data) - test_size
    for col in columns_not_in_prediction:
        for i in range(1, num_past_measurements + 1):
            data[f'{col}_{i}'] = data[col].shift(i * 25)
            if data[f'{col}_{i}'].dtype == 'int64':
                data[f'{col}_{i}'].fillna(-1, inplace=True)
            elif data[f'{col}_{i}'].dtype == 'float64':
                data[f'{col}_{i}'].fillna(-1.0, inplace=True)
            if data[f'{col}_{i}'].dtype != data[col].dtype:
                data[f'{col}_{i}'] = data[f'{col}_{i}'].astype(data[col].dtype)
            train_data.loc[:start_index, f'{col}_{i}'] = data.loc[:start_index, f'{col}_{i}']
            test_data.loc[:start_index, f'{col}_{i}'] = data.loc[:start_index, f'{col}_{i}']
            prediction_data.loc[start_index:, f'{col}_{i}'] = data.loc[start_index:, f'{col}_{i}']
    num_rows = int(np.round(len(train_data) * 0.05))
    scaler = StandardScaler()
    y_scaler = MinMaxScaler()
    for col in columns_not_in_prediction:
        features = [f'{col}_{i}' for i in range(1, num_columns)]
        X_test = prediction_data[features]
        if col in continuous_columns:
            X_train = train_data[features].values[-num_rows:]
            y_train = train_data[col].values[-num_rows:]
        else:
            X_train = train_data[features].values
            y_train = train_data[col].values
        min_value = y_train.min()
        y_train -= min_value
        y_train_scaled = y_scaler.fit_transform(y_train.reshape(-1, 1))
        X_train_scaled = scaler.fit_transform(X_train)
        X_test_scaled = scaler.transform(X_test)
        X_train_scaled = X_train_scaled.reshape((X_train_scaled.shape[0], X_train_scaled.shape[1], 1))
        X_test_scaled = X_test_scaled.reshape((X_test_scaled.shape[0], X_test_scaled.shape[1], 1))
        model = Sequential()
        model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train_scaled.shape[1], 1)))
        model.add(Flatten())
        if col in continuous_columns:
            model.add(Dense(1, activation='linear'))
            model.compile(loss='mean_squared_error', optimizer='adam')
        else:
            model.add(Dense(len(np.unique(y_train_scaled)), activation='softmax'))
            model.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'], optimizer='adam')
        model.fit(X_train_scaled, y_train_scaled, epochs=10, batch_size=128, verbose=0)
        y_pred_scaled = model.predict(X_test_scaled)
        if col in continuous_columns:
            y_pred = y_scaler.inverse_transform(y_pred_scaled.reshape(-1, 1))
        else:
            y_pred = y_pred_scaled
            y_pred = np.argmax(y_pred, axis=1)
        y_pred += min_value
        y_pred = np.where(y_pred < -1, -1, y_pred)
        if train_data[col].dtype == np.int64:
            y_pred = np.round(y_pred).astype(np.int64)
        prediction_data[col] = y_pred
    columns_to_drop = ['index']
    if columns_not_in_prediction:
        start_index = train_data.columns.get_loc(f'{columns_not_in_prediction[0]}_1')
        end_index = train_data.columns.get_loc(f'{columns_not_in_prediction[-1]}_{num_past_measurements}')
        columns_to_drop.extend(data.columns[start_index:end_index + 1])
    data = data.drop(columns_to_drop, axis=1)
    train_data = train_data.drop(columns_to_drop, axis=1)
    test_data = test_data.drop(columns_to_drop, axis=1)
    prediction_data = prediction_data.drop(columns_to_drop, axis=1)
    prediction_data = prediction_data[train_data.columns]
    scores = {}
    for col in prediction_data.columns:
        if col in continuous_columns:
            score = r2_score(test_data[col], prediction_data[col])
            if score < 0:
                score = 0
            metric = 'R-squared'
        else:
            score = accuracy_score(test_data[col], prediction_data[col])
            metric = 'Accuracy'
        scores[col] = (score, metric)
    average_score = np.mean([score for score, metric in scores.values()])
    average_score = round(average_score * 100, 2)
    table.add_row([file_path, f'{average_score}%'])
    table.add_row([''] * len(table.field_names))
print(table)
# Out:
# 266/266 [==============================] - 0s 1ms/step
# 266/266 [==============================] - 0s 1ms/step
# 266/266 [==============================] - 0s 1ms/step
# 266/266 [==============================] - 0s 1ms/step
# 266/266 [==============================] - 0s 1ms/step
# 266/266 [==============================] - 0s 1ms/step
# 266/266 [==============================] - 0s 1ms/step
# 266/266 [==============================] - 0s 1ms/step
# 266/266 [==============================] - 0s 1ms/step
# 266/266 [==============================] - 0s 1ms/step
# 266/266 [==============================] - 0s 1ms/step
# 266/266 [==============================] - 0s 1ms/step
# 266/266 [==============================] - 0s 1ms/step
# 235/235 [==============================] - 0s 1ms/step
# 235/235 [==============================] - 0s 1ms/step
# 235/235 [==============================] - 0s 1ms/step
# 235/235 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 58/58 [==============================] - 0s 1ms/step
# 58/58 [==============================] - 0s 1ms/step
# 58/58 [==============================] - 0s 2ms/step
# 58/58 [==============================] - 0s 2ms/step
# 58/58 [==============================] - 0s 1ms/step
# 58/58 [==============================] - 0s 1ms/step
# 58/58 [==============================] - 0s 1ms/step
# 58/58 [==============================] - 0s 1ms/step
# 58/58 [==============================] - 0s 2ms/step
# 58/58 [==============================] - 0s 1ms/step
# 58/58 [==============================] - 0s 2ms/step
# 29/29 [==============================] - 0s 2ms/step
# 29/29 [==============================] - 0s 2ms/step
# 78/78 [==============================] - 0s 2ms/step
# 78/78 [==============================] - 0s 1ms/step
# 78/78 [==============================] - 0s 2ms/step
# 78/78 [==============================] - 0s 1ms/step
# 78/78 [==============================] - 0s 1ms/step
# 78/78 [==============================] - 0s 1ms/step
# 78/78 [==============================] - 0s 1ms/step
# 78/78 [==============================] - 0s 2ms/step
# 78/78 [==============================] - 0s 1ms/step
# 78/78 [==============================] - 0s 2ms/step
# 78/78 [==============================] - 0s 1ms/step
# 39/39 [==============================] - 0s 2ms/step
# 39/39 [==============================] - 0s 1ms/step
# 77/77 [==============================] - 0s 2ms/step
# 77/77 [==============================] - 0s 2ms/step
# 77/77 [==============================] - 0s 2ms/step
# 77/77 [==============================] - 0s 1ms/step
# 77/77 [==============================] - 0s 1ms/step
# 42/42 [==============================] - 0s 1ms/step
# 42/42 [==============================] - 0s 1ms/step
# 45/45 [==============================] - 0s 2ms/step
# 45/45 [==============================] - 0s 2ms/step
# 45/45 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 56/56 [==============================] - 0s 2ms/step
# 56/56 [==============================] - 0s 1ms/step
# 56/56 [==============================] - 0s 1ms/step
# 56/56 [==============================] - 0s 1ms/step
# 56/56 [==============================] - 0s 1ms/step
# 56/56 [==============================] - 0s 1ms/step
# 56/56 [==============================] - 0s 1ms/step
# 56/56 [==============================] - 0s 1ms/step
# 56/56 [==============================] - 0s 1ms/step
# 56/56 [==============================] - 0s 1ms/step
# 56/56 [==============================] - 0s 1ms/step
# 56/56 [==============================] - 0s 2ms/step
# 29/29 [==============================] - 0s 2ms/step
# 29/29 [==============================] - 0s 2ms/step
# 29/29 [==============================] - 0s 1ms/step
# 29/29 [==============================] - 0s 2ms/step
# 29/29 [==============================] - 0s 1ms/step
# 28/28 [==============================] - 0s 2ms/step
# 28/28 [==============================] - 0s 1ms/step
# 28/28 [==============================] - 0s 1ms/step
# 76/76 [==============================] - 0s 1ms/step
# 76/76 [==============================] - 0s 1ms/step
# 76/76 [==============================] - 0s 1ms/step
# 76/76 [==============================] - 0s 1ms/step
# 76/76 [==============================] - 0s 1ms/step
# 76/76 [==============================] - 0s 1ms/step
# 76/76 [==============================] - 0s 1ms/step
# 76/76 [==============================] - 0s 1ms/step
# 76/76 [==============================] - 0s 1ms/step
# 76/76 [==============================] - 0s 1ms/step
# 76/76 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 1ms/step
#
    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/db_bench/mixgraph/qlt.csv             |     53.76%    |
# |                                                                                       |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/read_1/bclt.csv       |     57.55%    |
# |                                                                                       |               |
# |        /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/read_1/qlt.csv       |     60.0%     |
# |                                                                                       |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/read_2/bclt.csv       |     58.96%    |
# |                                                                                       |               |
# |        /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/read_2/qlt.csv       |     60.0%     |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_1/iolt.csv    |     60.03%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_1/qlt.csv    |     60.0%     |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_2/qlt.csv    |     43.68%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_3/qlt.csv    |     44.05%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_4/bclt.csv    |     51.75%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_4/iolt.csv    |     51.9%     |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_4/qlt.csv    |     43.81%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_5/bclt.csv    |     58.13%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_5/qlt.csv    |     60.0%     |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_6/qlt.csv    |     60.0%     |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_7/qlt.csv    |     60.0%     |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_8/bclt.csv    |     59.47%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_8/qlt.csv    |     60.0%     |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_1.csv   |     66.22%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_2.csv   |     64.49%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_3.csv   |     65.01%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_4.csv   |     64.69%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_5.csv   |     64.74%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_6.csv   |     65.23%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_7.csv   |     64.91%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_8.csv   |     65.1%     |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/iolt.csv    |     48.49%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/qlt.csv    |     60.0%     |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_1/bclt.csv    |     74.06%    |
# |                                                                                       |               |
# | /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_1/bclt_replay.csv |     67.99%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_1/iolt.csv    |     61.08%    |
# |                                                                                       |               |
# | /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_1/iolt_replay.csv |     56.74%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_1/qlt.csv     |     57.96%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_2/bclt_1.csv   |     48.92%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_2/bclt_2.csv   |     50.53%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_2/iolt.csv    |     51.79%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_2/qlt.csv     |     56.0%     |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_3/qlt.csv     |     58.0%     |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/updaterandom_1/bclt.csv   |     58.12%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/updaterandom_1/qlt.csv   |     35.43%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/updaterandom_2/bclt.csv   |     58.8%     |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/updaterandom_2/qlt.csv   |     33.75%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/updaterandom_3/bclt.csv   |     55.03%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/updaterandom_3/qlt.csv   |     35.3%     |
# |                                                                                       |               |
# |                   /content/drive/MyDrive/aaa/datasets/redis/bclt.csv                  |     79.55%    |
# |                                                                                       |               |
# |                   /content/drive/MyDrive/aaa/datasets/redis/iolt.csv                  |     43.25%    |
# |                                                                                       |               |
# |                   /content/drive/MyDrive/aaa/datasets/redis/qlt.csv                   |     80.0%     |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_1.csv             |     52.12%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_2.csv             |     43.95%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_3.csv             |     42.66%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_4.csv             |     42.31%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_5.csv             |     43.12%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_6.csv             |     45.2%     |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_7.csv             |     44.78%    |
# |                                                                                       |               |
# |              /content/drive/MyDrive/aaa/datasets/ycsb/workloada/qlt_1.csv             |     80.0%     |
# |                                                                                       |               |
# |              /content/drive/MyDrive/aaa/datasets/ycsb/workloada/qlt_2.csv             |     61.82%    |
# |                                                                                       |               |
# |              /content/drive/MyDrive/aaa/datasets/ycsb/workloadc/bclt.csv              |     79.78%    |
# |                                                                                       |               |
# |               /content/drive/MyDrive/aaa/datasets/ycsb/workloadc/qlt.csv              |     55.3%     |
# |                                                                                       |               |
# +---------------------------------------------------------------------------------------+---------------+

# %%
feature_name = 'HISTORY' ########################################################
test_ratio_in_percentage = 80 ########################################################
test_ratio = test_ratio_in_percentage / 100 ########################################################
table = PrettyTable()
table.field_names = ["Location", "Average Score"]
for csv_file in all_csv_files_sorted:
    file_path = os.path.join(root_folder, csv_file)
    data = pd.read_csv(file_path)
    data = data.head(int(np.round(len(data) * 0.001)))
    data = data.reset_index()
    test_size = int(np.round(len(data) * test_ratio))
    train_data, test_data = data[:-test_size], data[-test_size:]
    num_columns = train_data.shape[1]
    prediction_indices = range(len(train_data), len(train_data) + test_size)
    prediction_data = pd.DataFrame(prediction_indices, columns=['index'], index=prediction_indices)
    for col in [column for column in train_data.columns if train_data[column].nunique() == 1]:
        prediction_data[col] = pd.Series(train_data[col].iloc[0]).repeat(test_size).values
    columns_not_in_prediction = [col for col in train_data.columns.tolist() if col not in prediction_data.columns.tolist()]
    unique_values_dict = {}
    for col in columns_not_in_prediction:
        unique_values = train_data[col].nunique()
        unique_values_dict[col] = unique_values
    continuous_columns = []
    discrete_columns = []
    for col, unique_values in unique_values_dict.items():
        if unique_values > 500:
            continuous_columns.append(col)
        else:
            discrete_columns.append(col)
    num_past_measurements = 20
    start_index = len(data) - test_size
    for col in columns_not_in_prediction:
        for i in range(1, num_past_measurements + 1):
            data[f'{col}_{i}'] = data[col].shift(i * 25)
            if data[f'{col}_{i}'].dtype == 'int64':
                data[f'{col}_{i}'].fillna(-1, inplace=True)
            elif data[f'{col}_{i}'].dtype == 'float64':
                data[f'{col}_{i}'].fillna(-1.0, inplace=True)
            if data[f'{col}_{i}'].dtype != data[col].dtype:
                data[f'{col}_{i}'] = data[f'{col}_{i}'].astype(data[col].dtype)
            train_data.loc[:start_index, f'{col}_{i}'] = data.loc[:start_index, f'{col}_{i}']
            test_data.loc[:start_index, f'{col}_{i}'] = data.loc[:start_index, f'{col}_{i}']
            prediction_data.loc[start_index:, f'{col}_{i}'] = data.loc[start_index:, f'{col}_{i}']
    num_rows = int(np.round(len(train_data) * 0.05))
    scaler = StandardScaler()
    y_scaler = MinMaxScaler()
    for col in columns_not_in_prediction:
        features = [f'{col}_{i}' for i in range(1, num_columns)]
        X_test = prediction_data[features]
        if col in continuous_columns:
            X_train = train_data[features].values[-num_rows:]
            y_train = train_data[col].values[-num_rows:]
        else:
            X_train = train_data[features].values
            y_train = train_data[col].values
        min_value = y_train.min()
        y_train -= min_value
        y_train_scaled = y_scaler.fit_transform(y_train.reshape(-1, 1))
        X_train_scaled = scaler.fit_transform(X_train)
        X_test_scaled = scaler.transform(X_test)
        X_train_scaled = X_train_scaled.reshape((X_train_scaled.shape[0], X_train_scaled.shape[1], 1))
        X_test_scaled = X_test_scaled.reshape((X_test_scaled.shape[0], X_test_scaled.shape[1], 1))
        model = Sequential()
        model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train_scaled.shape[1], 1)))
        model.add(Flatten())
        if col in continuous_columns:
            model.add(Dense(1, activation='linear'))
            model.compile(loss='mean_squared_error', optimizer='adam')
        else:
            model.add(Dense(len(np.unique(y_train_scaled)), activation='softmax'))
            model.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'], optimizer='adam')
        model.fit(X_train_scaled, y_train_scaled, epochs=10, batch_size=128, verbose=0)
        y_pred_scaled = model.predict(X_test_scaled)
        if col in continuous_columns:
            y_pred = y_scaler.inverse_transform(y_pred_scaled.reshape(-1, 1))
        else:
            y_pred = y_pred_scaled
            y_pred = np.argmax(y_pred, axis=1)
        y_pred += min_value
        y_pred = np.where(y_pred < -1, -1, y_pred)
        if train_data[col].dtype == np.int64:
            y_pred = np.round(y_pred).astype(np.int64)
        prediction_data[col] = y_pred
    columns_to_drop = ['index']
    if columns_not_in_prediction:
        start_index = train_data.columns.get_loc(f'{columns_not_in_prediction[0]}_1')
        end_index = train_data.columns.get_loc(f'{columns_not_in_prediction[-1]}_{num_past_measurements}')
        columns_to_drop.extend(data.columns[start_index:end_index + 1])
    data = data.drop(columns_to_drop, axis=1)
    train_data = train_data.drop(columns_to_drop, axis=1)
    test_data = test_data.drop(columns_to_drop, axis=1)
    prediction_data = prediction_data.drop(columns_to_drop, axis=1)
    prediction_data = prediction_data[train_data.columns]
    scores = {}
    for col in prediction_data.columns:
        if col in continuous_columns:
            score = r2_score(test_data[col], prediction_data[col])
            if score < 0:
                score = 0
            metric = 'R-squared'
        else:
            score = accuracy_score(test_data[col], prediction_data[col])
            metric = 'Accuracy'
        scores[col] = (score, metric)
    average_score = np.mean([score for score, metric in scores.values()])
    average_score = round(average_score * 100, 2)
    table.add_row([file_path, f'{average_score}%'])
    table.add_row([''] * len(table.field_names))
print(table)
# Out:
# 426/426 [==============================] - 1s 1ms/step
# 426/426 [==============================] - 1s 1ms/step
# 426/426 [==============================] - 1s 1ms/step
# 426/426 [==============================] - 5s 1ms/step
# 426/426 [==============================] - 1s 1ms/step
# 426/426 [==============================] - 1s 1ms/step
# 426/426 [==============================] - 1s 1ms/step
# 426/426 [==============================] - 1s 1ms/step
# 426/426 [==============================] - 1s 1ms/step
# 426/426 [==============================] - 1s 2ms/step
# 426/426 [==============================] - 1s 1ms/step
# 426/426 [==============================] - 1s 1ms/step
# 426/426 [==============================] - 1s 1ms/step
# 375/375 [==============================] - 1s 2ms/step
# 375/375 [==============================] - 1s 1ms/step
# 375/375 [==============================] - 1s 1ms/step
# 375/375 [==============================] - 1s 1ms/step
# 501/501 [==============================] - 1s 1ms/step
# 501/501 [==============================] - 1s 1ms/step
# 501/501 [==============================] - 1s 1ms/step
# 501/501 [==============================] - 1s 1ms/step
# 501/501 [==============================] - 1s 1ms/step
# 501/501 [==============================] - 1s 1ms/step
# 501/501 [==============================] - 1s 1ms/step
# 501/501 [==============================] - 1s 1ms/step
# 501/501 [==============================] - 1s 1ms/step
# 501/501 [==============================] - 1s 1ms/step
# 500/500 [==============================] - 1s 1ms/step
# 500/500 [==============================] - 1s 1ms/step
# 501/501 [==============================] - 1s 1ms/step
# 501/501 [==============================] - 1s 1ms/step
# 501/501 [==============================] - 1s 1ms/step
# 501/501 [==============================] - 1s 1ms/step
# 501/501 [==============================] - 1s 1ms/step
# 501/501 [==============================] - 1s 1ms/step
# 501/501 [==============================] - 1s 1ms/step
# 501/501 [==============================] - 1s 1ms/step
# 501/501 [==============================] - 1s 1ms/step
# 501/501 [==============================] - 1s 1ms/step
# 500/500 [==============================] - 1s 1ms/step
# 500/500 [==============================] - 1s 1ms/step
# 7/7 [==============================] - 0s 3ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 25/25 [==============================] - 0s 1ms/step
# 25/25 [==============================] - 0s 1ms/step
# 25/25 [==============================] - 0s 2ms/step
# 25/25 [==============================] - 0s 1ms/step
# 92/92 [==============================] - 0s 1ms/step
# 92/92 [==============================] - 0s 1ms/step
# 92/92 [==============================] - 0s 1ms/step
# 92/92 [==============================] - 0s 2ms/step
# 92/92 [==============================] - 0s 1ms/step
# 92/92 [==============================] - 0s 1ms/step
# 92/92 [==============================] - 0s 1ms/step
# 92/92 [==============================] - 0s 1ms/step
# 92/92 [==============================] - 0s 1ms/step
# 92/92 [==============================] - 0s 2ms/step
# 92/92 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 46/46 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 2ms/step
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# 125/125 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 123/123 [==============================] - 0s 1ms/step
# 123/123 [==============================] - 0s 1ms/step
# 123/123 [==============================] - 0s 1ms/step
# 123/123 [==============================] - 0s 2ms/step
# 123/123 [==============================] - 0s 1ms/step
# 67/67 [==============================] - 0s 1ms/step
# 67/67 [==============================] - 0s 1ms/step
# 71/71 [==============================] - 0s 1ms/step
# 71/71 [==============================] - 0s 1ms/step
# 71/71 [==============================] - 0s 1ms/step
# 52/52 [==============================] - 0s 2ms/step
# 52/52 [==============================] - 0s 1ms/step
# 52/52 [==============================] - 0s 1ms/step
content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/qlt.csv           |     60.0%     |
# |                                                                                       |               |
# |            /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/iolt_1.csv            |     70.83%    |
# |                                                                                       |               |
# |            /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/iolt_2.csv            |     71.75%    |
# |                                                                                       |               |
# |              /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/qlt.csv             |     73.02%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/db_bench/mixgraph/iolt.csv            |     53.76%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/db_bench/mixgraph/qlt.csv             |     54.32%    |
# |                                                                                       |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/read_1/bclt.csv       |     58.04%    |
# |                                                                                       |               |
# |        /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/read_1/qlt.csv       |     60.0%     |
# |                                                                                       |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/read_2/bclt.csv       |     59.65%    |
# |                                                                                       |               |
# |        /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/read_2/qlt.csv       |     60.0%     |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_1/iolt.csv    |     50.35%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_1/qlt.csv    |     60.0%     |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_2/qlt.csv    |     43.93%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_3/qlt.csv    |     44.07%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_4/bclt.csv    |     52.52%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_4/iolt.csv    |     51.89%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_4/qlt.csv    |     43.95%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_5/bclt.csv    |     57.91%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_5/qlt.csv    |     60.0%     |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_6/qlt.csv    |     67.18%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_7/qlt.csv    |     60.0%     |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_8/bclt.csv    |     58.74%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_8/qlt.csv    |     60.0%     |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_1.csv   |     60.4%     |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_2.csv   |     59.65%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_3.csv   |     60.21%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_4.csv   |     60.28%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_5.csv   |     59.64%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_6.csv   |     60.27%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_7.csv   |     60.0%     |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_8.csv   |     60.38%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/iolt.csv    |     57.72%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/qlt.csv    |     60.0%     |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_1/bclt.csv    |     67.05%    |
# |                                                                                       |               |
# | /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_1/bclt_replay.csv |     68.19%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_1/iolt.csv    |     61.25%    |
# |                                                                                       |               |
# | /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_1/iolt_replay.csv |     55.73%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_1/qlt.csv     |     55.92%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_2/bclt_1.csv   |     44.77%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_2/bclt_2.csv   |     50.27%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_2/iolt.csv    |     51.81%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_2/qlt.csv     |     56.0%     |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_3/qlt.csv     |     58.0%     |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/updaterandom_1/bclt.csv   |     59.4%     |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/updaterandom_1/qlt.csv   |     34.98%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/updaterandom_2/bclt.csv   |     60.86%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/updaterandom_2/qlt.csv   |     35.96%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/updaterandom_3/bclt.csv   |     55.29%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/updaterandom_3/qlt.csv   |     36.97%    |
# |                                                                                       |               |
# |                   /content/drive/MyDrive/aaa/datasets/redis/bclt.csv                  |     77.36%    |
# |                                                                                       |               |
# |                   /content/drive/MyDrive/aaa/datasets/redis/iolt.csv                  |     45.0%     |
# |                                                                                       |               |
# |                   /content/drive/MyDrive/aaa/datasets/redis/qlt.csv                   |     80.0%     |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_1.csv             |     57.91%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_2.csv             |     43.89%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_3.csv             |     42.51%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_4.csv             |     42.35%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_5.csv             |     43.13%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_6.csv             |     45.06%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_7.csv             |     44.66%    |
# |                                                                                       |               |
# |              /content/drive/MyDrive/aaa/datasets/ycsb/workloada/qlt_1.csv             |     80.0%     |
# |                                                                                       |               |
# |              /content/drive/MyDrive/aaa/datasets/ycsb/workloada/qlt_2.csv             |     61.78%    |
# |                                                                                       |               |
# |              /content/drive/MyDrive/aaa/datasets/ycsb/workloadc/bclt.csv              |     70.33%    |
# |                                                                                       |               |
# |               /content/drive/MyDrive/aaa/datasets/ycsb/workloadc/qlt.csv              |     37.65%    |
# |                                                                                       |               |
# +---------------------------------------------------------------------------------------+---------------+
