# %%
from google.colab import drive
from keras.layers import Dense, Dropout, Flatten, GRU
from keras.models import Sequential
from natsort import natsorted
from prettytable import PrettyTable
from sklearn.metrics import accuracy_score, r2_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import numpy as np
import os
import pandas as pd
import warnings
drive.mount('/content/drive')
warnings.filterwarnings('ignore')
root_folder = '/content/drive/MyDrive/aaa/datasets'
def find_and_sort_csv_files(folder):
    csv_files = []
    for root, dirs, files in os.walk(folder):
        for file in files:
            if file.endswith('.csv'):
                csv_files.append(os.path.join(root, file))
    csv_files_sorted = natsorted(csv_files)
    return csv_files_sorted
all_csv_files_sorted = find_and_sort_csv_files(root_folder)
feature_name = 'HISTORY' ########################################################
test_ratio_in_percentage = 20 ########################################################
test_ratio = test_ratio_in_percentage / 100 ########################################################
table = PrettyTable()
table.field_names = ["Location", "Average Score"]
for csv_file in all_csv_files_sorted:
    file_path = os.path.join(root_folder, csv_file)
    data = pd.read_csv(file_path)
    data = data.head(int(np.round(len(data) * 0.001)))
    data = data.reset_index()
    test_size = int(np.round(len(data) * test_ratio))
    train_data, test_data = data[:-test_size], data[-test_size:]
    num_columns = train_data.shape[1]
    prediction_indices = range(len(train_data), len(train_data) + test_size)
    prediction_data = pd.DataFrame(prediction_indices, columns=['index'], index=prediction_indices)
    for col in [column for column in train_data.columns if train_data[column].nunique() == 1]:
        prediction_data[col] = pd.Series(train_data[col].iloc[0]).repeat(test_size).values
    columns_not_in_prediction = [col for col in train_data.columns.tolist() if col not in prediction_data.columns.tolist()]
    unique_values_dict = {}
    for col in columns_not_in_prediction:
        unique_values = train_data[col].nunique()
        unique_values_dict[col] = unique_values
    continuous_columns = []
    discrete_columns = []
    for col, unique_values in unique_values_dict.items():
        if unique_values > 500:
            continuous_columns.append(col)
        else:
            discrete_columns.append(col)
    num_past_measurements = 20
    start_index = len(data) - test_size
    for col in columns_not_in_prediction:
        for i in range(1, num_past_measurements + 1):
            data[f'{col}_{i}'] = data[col].shift(i * 25)
            if data[f'{col}_{i}'].dtype == 'int64':
                data[f'{col}_{i}'].fillna(-1, inplace=True)
            elif data[f'{col}_{i}'].dtype == 'float64':
                data[f'{col}_{i}'].fillna(-1.0, inplace=True)
            if data[f'{col}_{i}'].dtype != data[col].dtype:
                data[f'{col}_{i}'] = data[f'{col}_{i}'].astype(data[col].dtype)
            train_data.loc[:start_index, f'{col}_{i}'] = data.loc[:start_index, f'{col}_{i}']
            test_data.loc[:start_index, f'{col}_{i}'] = data.loc[:start_index, f'{col}_{i}']
            prediction_data.loc[start_index:, f'{col}_{i}'] = data.loc[start_index:, f'{col}_{i}']
    num_rows = int(np.round(len(train_data) * 0.05))
    scaler = StandardScaler()
    y_scaler = MinMaxScaler()
    for col in columns_not_in_prediction:
        features = [f'{col}_{i}' for i in range(1, num_columns)]
        X_test = prediction_data[features]
        if col in continuous_columns:
            X_train = train_data[features].values[-num_rows:]
            y_train = train_data[col].values[-num_rows:]
        else:
            X_train = train_data[features].values
            y_train = train_data[col].values
        min_value = y_train.min()
        y_train -= min_value
        y_train_scaled = y_scaler.fit_transform(y_train.reshape(-1, 1))
        X_train_scaled = scaler.fit_transform(X_train)
        X_test_scaled = scaler.transform(X_test)
        X_train_scaled = X_train_scaled.reshape((X_train_scaled.shape[0], X_train_scaled.shape[1], 1))
        X_test_scaled = X_test_scaled.reshape((X_test_scaled.shape[0], X_test_scaled.shape[1], 1))
        model = Sequential()
        model.add(GRU(128, return_sequences=True, input_shape=(X_train_scaled.shape[1], X_train_scaled.shape[2])))
        model.add(Dropout(0.2))
        model.add(GRU(128, return_sequences=True))
        model.add(Dropout(0.2))
        model.add(GRU(128))
        model.add(Dropout(0.2))
        model.add(Flatten())
        if col in continuous_columns:
            model.add(Dense(1, activation='linear'))
            model.compile(loss='mean_squared_error', optimizer='adam')
        else:
            model.add(Dense(len(np.unique(y_train_scaled)), activation='softmax'))
            model.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'], optimizer='adam')
        model.fit(X_train_scaled, y_train_scaled, epochs=10, batch_size=128, verbose=0)
        y_pred_scaled = model.predict(X_test_scaled)
        if col in continuous_columns:
            y_pred = y_scaler.inverse_transform(y_pred_scaled.reshape(-1, 1))
        else:
            y_pred = y_pred_scaled
            y_pred = np.argmax(y_pred, axis=1)
        y_pred += min_value
        y_pred = np.where(y_pred < -1, -1, y_pred)
        if train_data[col].dtype == np.int64:
            y_pred = np.round(y_pred).astype(np.int64)
        prediction_data[col] = y_pred
    columns_to_drop = ['index']
    if columns_not_in_prediction:
        start_index = train_data.columns.get_loc(f'{columns_not_in_prediction[0]}_1')
        end_index = train_data.columns.get_loc(f'{columns_not_in_prediction[-1]}_{num_past_measurements}')
        columns_to_drop.extend(data.columns[start_index:end_index + 1])
    data = data.drop(columns_to_drop, axis=1)
    train_data = train_data.drop(columns_to_drop, axis=1)
    test_data = test_data.drop(columns_to_drop, axis=1)
    prediction_data = prediction_data.drop(columns_to_drop, axis=1)
    prediction_data = prediction_data[train_data.columns]
    scores = {}
    for col in prediction_data.columns:
        if col in continuous_columns:
            score = r2_score(test_data[col], prediction_data[col])
            if score < 0:
                score = 0
            metric = 'R-squared'
        else:
            score = accuracy_score(test_data[col], prediction_data[col])
            metric = 'Accuracy'
        scores[col] = (score, metric)
    average_score = np.mean([score for score, metric in scores.values()])
    average_score = round(average_score * 100, 2)
    table.add_row([file_path, f'{average_score}%'])
    table.add_row([''] * len(table.field_names))
print(table)
# Out:
# Mounted at /content/drive
# 107/107 [==============================] - 1s 2ms/step
# 107/107 [==============================] - 1s 2ms/step
# 107/107 [==============================] - 1s 3ms/step
# 107/107 [==============================] - 1s 3ms/step
# 107/107 [==============================] - 1s 3ms/step
# 107/107 [==============================] - 1s 3ms/step
# 107/107 [==============================] - 1s 3ms/step
# 107/107 [==============================] - 1s 3ms/step
# 107/107 [==============================] - 2s 3ms/step
# 107/107 [==============================] - 1s 3ms/step
# 107/107 [==============================] - 1s 3ms/step
# 107/107 [==============================] - 1s 3ms/step
# 107/107 [==============================] - 1s 2ms/step
# 94/94 [==============================] - 1s 2ms/step
# 94/94 [==============================] - 1s 2ms/step
# 94/94 [==============================] - 1s 3ms/step
# 94/94 [==============================] - 1s 2ms/step
# 126/126 [==============================] - 1s 2ms/step
# 126/126 [==============================] - 1s 2ms/step
# 126/126 [==============================] - 1s 3ms/step
# 126/126 [==============================] - 1s 3ms/step
# 126/126 [==============================] - 1s 2ms/step
# 126/126 [==============================] - 1s 3ms/step
# 126/126 [==============================] - 1s 3ms/step
# 126/126 [==============================] - 1s 2ms/step
# 126/126 [==============================] - 1s 3ms/step
# 126/126 [==============================] - 1s 2ms/step
# 125/125 [==============================] - 1s 2ms/step
# 125/125 [==============================] - 1s 2ms/step
# 125/125 [==============================] - 1s 2ms/step
# 125/125 [==============================] - 1s 2ms/step
# 125/125 [==============================] - 1s 2ms/step
# 125/125 [==============================] - 1s 2ms/step
# 125/125 [==============================] - 1s 2ms/step
# 125/125 [==============================] - 1s 2ms/step
# 125/125 [==============================] - 1s 2ms/step
# 125/125 [==============================] - 1s 2ms/step
# 125/125 [==============================] - 1s 2ms/step
# 125/125 [==============================] - 1s 2ms/step
# 125/125 [==============================] - 1s 2ms/step
# 125/125 [==============================] - 1s 2ms/step
# 2/2 [==============================] - 1s 5ms/step
# 2/2 [==============================] - 1s 5ms/step
# 2/2 [==============================] - 1s 5ms/step
# WARNING:tensorflow:5 out of the last 132 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe3422d0af0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 1s 5ms/step
# WARNING:tensorflow:6 out of the last 134 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe363fd45e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 1s 5ms/step
# 7/7 [==============================] - 1s 3ms/step
# 7/7 [==============================] - 1s 3ms/step
# 7/7 [==============================] - 1s 3ms/step
# 7/7 [==============================] - 1s 3ms/step
# 23/23 [==============================] - 1s 3ms/step
# 23/23 [==============================] - 1s 3ms/step
# 23/23 [==============================] - 1s 3ms/step
# 23/23 [==============================] - 1s 3ms/step
# 23/23 [==============================] - 1s 3ms/step
# 23/23 [==============================] - 1s 3ms/step
# 23/23 [==============================] - 1s 3ms/step
# 23/23 [==============================] - 1s 3ms/step
# 23/23 [==============================] - 1s 3ms/step
# 23/23 [==============================] - 1s 3ms/step
# 23/23 [==============================] - 1s 3ms/step
# 12/12 [==============================] - 1s 3ms/step
# 12/12 [==============================] - 1s 3ms/step
# 32/32 [==============================] - 1s 3ms/step
# 32/32 [==============================] - 1s 3ms/step
# 32/32 [==============================] - 1s 3ms/step
# 32/32 [==============================] - 4s 4ms/step
# 32/32 [==============================] - 1s 3ms/step
# 32/32 [==============================] - 1s 3ms/step
# 32/32 [==============================] - 1s 3ms/step
# 32/32 [==============================] - 1s 3ms/step
# 32/32 [==============================] - 1s 3ms/step
# 32/32 [==============================] - 1s 3ms/step
# 32/32 [==============================] - 1s 3ms/step
# 16/16 [==============================] - 1s 3ms/step
# 16/16 [==============================] - 1s 2ms/step
# 31/31 [==============================] - 1s 3ms/step
# 31/31 [==============================] - 1s 3ms/step
# 31/31 [==============================] - 1s 3ms/step
# 31/31 [==============================] - 1s 3ms/step
# 31/31 [==============================] - 1s 3ms/step
# 17/17 [==============================] - 1s 3ms/step
# 17/17 [==============================] - 1s 3ms/step
# 18/18 [==============================] - 1s 2ms/step
# 18/18 [==============================] - 1s 2ms/step
# 18/18 [==============================] - 1s 2ms/step
# 13/13 [==============================] - 1s 3ms/step
# 13/13 [==============================] - 1s 3ms/step
# 13/13 [==============================] - 1s 3ms/step
# 23/23 [==============================] - 1s 3ms/step
# 23/23 [==============================] - 1s 3ms/step
# 23/23 [==============================] - 1s 3ms/step
# 23/23 [==============================] - 1s 3ms/step
# 23/23 [==============================] - 1s 3ms/step
# 23/23 [==============================] - 1s 3ms/step
# 23/23 [==============================] - 1s 3ms/step
# 23/23 [==============================] - 1s 3ms/step
# 23/23 [==============================] - 1s 3ms/step
# 23/23 [==============================] - 1s 3ms/step
# 23/23 [==============================] - 1s 3ms/step
# 23/23 [==============================] - 1s 3ms/step
# 12/12 [==============================] - 1s 3ms/step
# 12/12 [==============================] - 1s 3ms/step
# 12/12 [==============================] - 1s 3ms/step
# 12/12 [==============================] - 1s 3ms/step
# 12/12 [==============================] - 1s 3ms/step
# 12/12 [==============================] - 1s 3ms/step
# 12/12 [==============================] - 1s 3ms/step
# 12/12 [==============================] - 1s 3ms/step
# 31/31 [==============================] - 1s 3ms/step
# 31/31 [==============================] - 1s 3ms/step
# 31/31 [==============================] - 1s 3ms/step
# 31/31 [==============================] - 1s 3ms/step
# 31/31 [==============================] - 1s 3ms/step
# 31/31 [==============================] - 1s 3ms/step
# 31/31 [==============================] - 1s 3ms/step
# 31/31 [==============================] - 1s 3ms/step
# 31/31 [==============================] - 1s 3ms/step
# 31/31 [==============================] - 1s 3ms/step
# 31/31 [==============================] - 1s 3ms/step
# 16/16 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 2ms/step
# 17/17 [==============================] - 1s 3ms/step
# 17/17 [==============================] - 1s 3ms/step
# 34/34 [==============================] - 1s 3ms/step
# 34/34 [==============================] - 1s 3ms/step
# 34/34 [==============================] - 1s 3ms/step
# 34/34 [==============================] - 1s 3ms/step
# 34/34 [==============================] - 1s 3ms/step
# 34/34 [==============================] - 1s 3ms/step
# 34/34 [==============================] - 1s 3ms/step
# 34/34 [==============================] - 1s 3ms/step
# 34/34 [==============================] - 1s 3ms/step
# 34/34 [==============================] - 1s 3ms/step
# 34/34 [==============================] - 1s 3ms/step
# 17/17 [==============================] - 1s 3ms/step
# 17/17 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 7s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 54/54 [==============================] - 1s 3ms/step
# 54/54 [==============================] - 1s 3ms/step
# 54/54 [==============================] - 1s 3ms/step
# 54/54 [==============================] - 1s 3ms/step
# 54/54 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 3ms/step
# 29/29 [==============================] - 1s 3ms/step
# 29/29 [==============================] - 1s 3ms/step
# 29/29 [==============================] - 1s 3ms/step
# 29/29 [==============================] - 1s 3ms/step
# 29/29 [==============================] - 1s 3ms/step
# 29/29 [==============================] - 1s 3ms/step
# 29/29 [==============================] - 1s 3ms/step
# 29/29 [==============================] - 1s 3ms/step
# 29/29 [==============================] - 1s 3ms/step
# 29/29 [==============================] - 1s 3ms/step
# 27/27 [==============================] - 1s 3ms/step
# 27/27 [==============================] - 1s 3ms/step
# 27/27 [==============================] - 1s 3ms/step
# 27/27 [==============================] - 1s 3ms/step
# 27/27 [==============================] - 1s 3ms/step
# 27/27 [==============================] - 1s 3ms/step
# 27/27 [==============================] - 1s 3ms/step
# 27/27 [==============================] - 1s 3ms/step
# 27/27 [==============================] - 1s 3ms/step
# 14/14 [==============================] - 1s 3ms/step
# 14/14 [==============================] - 1s 3ms/step
# 14/14 [==============================] - 1s 3ms/step
# 14/14 [==============================] - 1s 3ms/step
# 27/27 [==============================] - 1s 3ms/step
# 27/27 [==============================] - 1s 3ms/step
# 27/27 [==============================] - 1s 3ms/step
# 27/27 [==============================] - 1s 3ms/step
# 27/27 [==============================] - 1s 3ms/step
# 27/27 [==============================] - 1s 3ms/step
# 27/27 [==============================] - 1s 3ms/step
# 27/27 [==============================] - 1s 3ms/step
# 19/19 [==============================] - 1s 2ms/step
# 19/19 [==============================] - 1s 3ms/step
# 19/19 [==============================] - 1s 3ms/step
# 19/19 [==============================] - 1s 2ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 41/41 [==============================] - 1s 3ms/step
# 7/7 [==============================] - 1s 3ms/step
# 7/7 [==============================] - 1s 3ms/step
# 7/7 [==============================] - 1s 3ms/step
# 7/7 [==============================] - 1s 3ms/step
# 7/7 [==============================] - 1s 3ms/step
# 7/7 [==============================] - 1s 3ms/step
# 7/7 [==============================] - 1s 3ms/step
# 7/7 [==============================] - 1s 3ms/step
# 7/7 [==============================] - 1s 3ms/step
# 7/7 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 1s 2ms/step
# 63/63 [==============================] - 1s 3ms/step
# 63/63 [==============================] - 1s 3ms/step
# 24/24 [==============================] - 1s 3ms/step
# 24/24 [==============================] - 1s 3ms/step
# 24/24 [==============================] - 1s 3ms/step
# 24/24 [==============================] - 1s 3ms/step
# 24/24 [==============================] - 1s 3ms/step
# 24/24 [==============================] - 1s 3ms/step
# 24/24 [==============================] - 1s 3ms/step
# 24/24 [==============================] - 1s 3ms/step
# 24/24 [==============================] - 1s 3ms/step
# 24/24 [==============================] - 1s 3ms/step
# 24/24 [==============================] - 1s 3ms/step
# 14/14 [==============================] - 1s 3ms/step
# 14/14 [==============================] - 1s 2ms/step
# 14/14 [==============================] - 1s 2ms/step
# 14/14 [==============================] - 1s 3ms/step
# 21/21 [==============================] - 1s 3ms/step
# 21/21 [==============================] - 1s 3ms/step
# 21/21 [==============================] - 1s 3ms/step
# 21/21 [==============================] - 1s 3ms/step
# 21/21 [==============================] - 1s 3ms/step
# 21/21 [==============================] - 1s 3ms/step
# 21/21 [==============================] - 1s 3ms/step
# 21/21 [==============================] - 1s 3ms/step
# 21/21 [==============================] - 1s 3ms/step
# 21/21 [==============================] - 1s 3ms/step
# 21/21 [==============================] - 1s 3ms/step
# 13/13 [==============================] - 1s 3ms/step
# 13/13 [==============================] - 1s 2ms/step
# 13/13 [==============================] - 1s 3ms/step
# 13/13 [==============================] - 1s 3ms/step
# 30/30 [==============================] - 1s 3ms/step
# 30/30 [==============================] - 1s 3ms/step
# 30/30 [==============================] - 1s 3ms/step
# 30/30 [==============================] - 1s 3ms/step
# 30/30 [==============================] - 1s 3ms/step
# 30/30 [==============================] - 1s 3ms/step
# 30/30 [==============================] - 1s 3ms/step
# 30/30 [==============================] - 1s 3ms/step
# 30/30 [==============================] - 1s 3ms/step
# 30/30 [==============================] - 1s 3ms/step
# 30/30 [==============================] - 1s 3ms/step
# 30/30 [==============================] - 1s 3ms/step
# 17/17 [==============================] - 1s 3ms/step
# 17/17 [==============================] - 1s 3ms/step
# 17/17 [==============================] - 1s 3ms/step
# 17/17 [==============================] - 1s 3ms/step
# 2/2 [==============================] - 1s 6ms/step
# 2/2 [==============================] - 1s 6ms/step
# 2/2 [==============================] - 1s 5ms/step
# 2/2 [==============================] - 1s 6ms/step
# 2/2 [==============================] - 1s 5ms/step
# 2/2 [==============================] - 1s 6ms/step
# 2/2 [==============================] - 1s 6ms/step
# 13/13 [==============================] - 1s 3ms/step
# 13/13 [==============================] - 1s 3ms/step
# 13/13 [==============================] - 1s 3ms/step
# 13/13 [==============================] - 1s 3ms/step
# 13/13 [==============================] - 1s 3ms/step
# 13/13 [==============================] - 1s 3ms/step
# 13/13 [==============================] - 1s 3ms/step
# 13/13 [==============================] - 1s 3ms/step
# 13/13 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 70/70 [==============================] - 1s 3ms/step
# 101/101 [==============================] - 1s 3ms/step
# 101/101 [==============================] - 1s 3ms/step
# 101/101 [==============================] - 1s 2ms/step
# 101/101 [==============================] - 1s 2ms/step
# 101/101 [==============================] - 1s 2ms/step
# 101/101 [==============================] - 1s 2ms/step
# 101/101 [==============================] - 1s 3ms/step
# 20/20 [==============================] - 1s 3ms/step
# 20/20 [==============================] - 1s 3ms/step
# 20/20 [==============================] - 1s 3ms/step
# 20/20 [==============================] - 1s 3ms/step
# 20/20 [==============================] - 1s 3ms/step
# 20/20 [==============================] - 1s 3ms/step
# 20/20 [==============================] - 1s 3ms/step
# 20/20 [==============================] - 1s 3ms/step
# 20/20 [==============================] - 1s 3ms/step
# 20/20 [==============================] - 1s 3ms/step
# 20/20 [==============================] - 1s 3ms/step
# 20/20 [==============================] - 1s 3ms/step
# 119/119 [==============================] - 1s 2ms/step
# 119/119 [==============================] - 1s 2ms/step
# 119/119 [==============================] - 1s 2ms/step
# 119/119 [==============================] - 1s 2ms/step
# 119/119 [==============================] - 1s 3ms/step
# +---------------------------------------------------------------------------------------+---------------+
# |                                        Location                                       | Average Score |
# +---------------------------------------------------------------------------------------+---------------+
# |          /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/iolt_1.csv         |     73.73%    |
# |                                                                                       |               |
# |          /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/iolt_2.csv         |     31.36%    |
# |                                                                                       |               |
# |          /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/qlt_1.csv          |     60.0%     |
# |                                                                                       |               |
# |          /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/qlt_2.csv          |     60.0%     |
# |                                                                                       |               |
# |          /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/iolt_1.csv         |     71.96%    |
# |                                                                                       |               |
# |          /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/iolt_2.csv         |     83.09%    |
# |                                                                                       |               |
# |           /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/qlt.csv           |     60.0%     |
# |                                                                                       |               |
# |            /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/iolt_1.csv            |     70.15%    |
# |                                                                                       |               |
# |            /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/iolt_2.csv            |     74.52%    |
# |                                                                                       |               |
# |              /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/qlt.csv             |     64.16%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/db_bench/mixgraph/iolt.csv            |     61.51%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/db_bench/mixgraph/qlt.csv             |     54.1%     |
# |                                                                                       |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/read_1/bclt.csv       |     62.18%    |
# |                                                                                       |               |
# |        /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/read_1/qlt.csv       |     60.0%     |
# |                                                                                       |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/read_2/bclt.csv       |     62.27%    |
# |                                                                                       |               |
# |        /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/read_2/qlt.csv       |     60.0%     |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_1/iolt.csv    |     50.53%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_1/qlt.csv    |     60.0%     |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_2/qlt.csv    |     44.28%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_3/qlt.csv    |     44.4%     |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_4/bclt.csv    |     58.09%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_4/iolt.csv    |     54.72%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_4/qlt.csv    |     44.28%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_5/bclt.csv    |     65.65%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_5/qlt.csv    |     60.0%     |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_6/qlt.csv    |     66.95%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_7/qlt.csv    |     60.0%     |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_8/bclt.csv    |     64.54%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_8/qlt.csv    |     60.0%     |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_1.csv   |     68.51%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_2.csv   |     66.85%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_3.csv   |     65.94%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_4.csv   |     64.94%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_5.csv   |     65.33%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_6.csv   |     65.44%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_7.csv   |     66.29%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/bclt_8.csv   |     64.98%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/iolt.csv    |     48.39%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readrandom_9/qlt.csv    |     60.0%     |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_1/bclt.csv    |     72.85%    |
# |                                                                                       |               |
# | /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_1/bclt_replay.csv |     72.95%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_1/iolt.csv    |     62.85%    |
# |                                                                                       |               |
# | /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_1/iolt_replay.csv |     46.04%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_1/qlt.csv     |     57.96%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_2/bclt_1.csv   |     51.45%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_2/bclt_2.csv   |     51.92%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_2/iolt.csv    |     57.32%    |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_2/qlt.csv     |     58.0%     |
# |                                                                                       |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/readwrite_3/qlt.csv     |     58.0%     |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/updaterandom_1/bclt.csv   |     64.06%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/updaterandom_1/qlt.csv   |     40.0%     |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/updaterandom_2/bclt.csv   |     64.34%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/updaterandom_2/qlt.csv   |     40.14%    |
# |                                                                                       |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/updaterandom_3/bclt.csv   |     62.76%    |
# |                                                                                       |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/updaterandom_3/qlt.csv   |     39.96%    |
# |                                                                                       |               |
# |                   /content/drive/MyDrive/aaa/datasets/redis/bclt.csv                  |     80.0%     |
# |                                                                                       |               |
# |                   /content/drive/MyDrive/aaa/datasets/redis/iolt.csv                  |     31.18%    |
# |                                                                                       |               |
# |                   /content/drive/MyDrive/aaa/datasets/redis/qlt.csv                   |     80.0%     |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_1.csv             |     52.87%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_2.csv             |     48.41%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_3.csv             |     47.38%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_4.csv             |     46.1%     |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_5.csv             |     47.67%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_6.csv             |     49.58%    |
# |                                                                                       |               |
# |             /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_7.csv             |     49.25%    |
# |                                                                                       |               |
# |              /content/drive/MyDrive/aaa/datasets/ycsb/workloada/qlt_1.csv             |     80.0%     |
# |                                                                                       |               |
# |              /content/drive/MyDrive/aaa/datasets/ycsb/workloada/qlt_2.csv             |     64.13%    |
# |                                                                                       |               |
# |              /content/drive/MyDrive/aaa/datasets/ycsb/workloadc/bclt.csv              |     84.9%     |
# |                                                                                       |               |
# |               /content/drive/MyDrive/aaa/datasets/ycsb/workloadc/qlt.csv              |     60.0%     |
# |                                                                                       |               |
# +---------------------------------------------------------------------------------------+---------------+

# %%
from google.colab import drive
from keras.layers import Dense, Dropout, Flatten, GRU
from keras.models import Sequential
from natsort import natsorted
from prettytable import PrettyTable
from sklearn.metrics import accuracy_score, r2_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import numpy as np
import os
import pandas as pd
import warnings
drive.mount('/content/drive')
warnings.filterwarnings('ignore')
root_folder = '/content/drive/MyDrive/aaa/datasets'
def find_and_sort_csv_files(folder):
    csv_files = []
    for root, dirs, files in os.walk(folder):
        for file in files:
            if file.endswith('.csv'):
                csv_files.append(os.path.join(root, file))
    csv_files_sorted = natsorted(csv_files)
    return csv_files_sorted
all_csv_files_sorted = find_and_sort_csv_files(root_folder)
feature_name = 'HISTORY' ########################################################
test_ratio_in_percentage = 50 ########################################################
test_ratio = test_ratio_in_percentage / 100 ########################################################
table = PrettyTable()
table.field_names = ["Location", "Average Score"]
for csv_file in all_csv_files_sorted:
    file_path = os.path.join(root_folder, csv_file)
    data = pd.read_csv(file_path)
    data = data.head(int(np.round(len(data) * 0.001)))
    data = data.reset_index()
    test_size = int(np.round(len(data) * test_ratio))
    train_data, test_data = data[:-test_size], data[-test_size:]
    num_columns = train_data.shape[1]
    prediction_indices = range(len(train_data), len(train_data) + test_size)
    prediction_data = pd.DataFrame(prediction_indices, columns=['index'], index=prediction_indices)
    for col in [column for column in train_data.columns if train_data[column].nunique() == 1]:
        prediction_data[col] = pd.Series(train_data[col].iloc[0]).repeat(test_size).values
    columns_not_in_prediction = [col for col in train_data.columns.tolist() if col not in prediction_data.columns.tolist()]
    unique_values_dict = {}
    for col in columns_not_in_prediction:
        unique_values = train_data[col].nunique()
        unique_values_dict[col] = unique_values
    continuous_columns = []
    discrete_columns = []
    for col, unique_values in unique_values_dict.items():
        if unique_values > 500:
            continuous_columns.append(col)
        else:
            discrete_columns.append(col)
    num_past_measurements = 20
    start_index = len(data) - test_size
    for col in columns_not_in_prediction:
        for i in range(1, num_past_measurements + 1):
            data[f'{col}_{i}'] = data[col].shift(i * 25)
            if data[f'{col}_{i}'].dtype == 'int64':
                data[f'{col}_{i}'].fillna(-1, inplace=True)
            elif data[f'{col}_{i}'].dtype == 'float64':
                data[f'{col}_{i}'].fillna(-1.0, inplace=True)
            if data[f'{col}_{i}'].dtype != data[col].dtype:
                data[f'{col}_{i}'] = data[f'{col}_{i}'].astype(data[col].dtype)
            train_data.loc[:start_index, f'{col}_{i}'] = data.loc[:start_index, f'{col}_{i}']
            test_data.loc[:start_index, f'{col}_{i}'] = data.loc[:start_index, f'{col}_{i}']
            prediction_data.loc[start_index:, f'{col}_{i}'] = data.loc[start_index:, f'{col}_{i}']
    num_rows = int(np.round(len(train_data) * 0.05))
    scaler = StandardScaler()
    y_scaler = MinMaxScaler()
    for col in columns_not_in_prediction:
        features = [f'{col}_{i}' for i in range(1, num_columns)]
        X_test = prediction_data[features]
        if col in continuous_columns:
            X_train = train_data[features].values[-num_rows:]
            y_train = train_data[col].values[-num_rows:]
        else:
            X_train = train_data[features].values
            y_train = train_data[col].values
        min_value = y_train.min()
        y_train -= min_value
        y_train_scaled = y_scaler.fit_transform(y_train.reshape(-1, 1))
        X_train_scaled = scaler.fit_transform(X_train)
        X_test_scaled = scaler.transform(X_test)
        X_train_scaled = X_train_scaled.reshape((X_train_scaled.shape[0], X_train_scaled.shape[1], 1))
        X_test_scaled = X_test_scaled.reshape((X_test_scaled.shape[0], X_test_scaled.shape[1], 1))
        model = Sequential()
        model.add(GRU(128, return_sequences=True, input_shape=(X_train_scaled.shape[1], X_train_scaled.shape[2])))
        model.add(Dropout(0.2))
        model.add(GRU(128, return_sequences=True))
        model.add(Dropout(0.2))
        model.add(GRU(128))
        model.add(Dropout(0.2))
        model.add(Flatten())
        if col in continuous_columns:
            model.add(Dense(1, activation='linear'))
            model.compile(loss='mean_squared_error', optimizer='adam')
        else:
            model.add(Dense(len(np.unique(y_train_scaled)), activation='softmax'))
            model.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'], optimizer='adam')
        model.fit(X_train_scaled, y_train_scaled, epochs=10, batch_size=128, verbose=0)
        y_pred_scaled = model.predict(X_test_scaled)
        if col in continuous_columns:
            y_pred = y_scaler.inverse_transform(y_pred_scaled.reshape(-1, 1))
        else:
            y_pred = y_pred_scaled
            y_pred = np.argmax(y_pred, axis=1)
        y_pred += min_value
        y_pred = np.where(y_pred < -1, -1, y_pred)
        if train_data[col].dtype == np.int64:
            y_pred = np.round(y_pred).astype(np.int64)
        prediction_data[col] = y_pred
    columns_to_drop = ['index']
    if columns_not_in_prediction:
        start_index = train_data.columns.get_loc(f'{columns_not_in_prediction[0]}_1')
        end_index = train_data.columns.get_loc(f'{columns_not_in_prediction[-1]}_{num_past_measurements}')
        columns_to_drop.extend(data.columns[start_index:end_index + 1])
    data = data.drop(columns_to_drop, axis=1)
    train_data = train_data.drop(columns_to_drop, axis=1)
    test_data = test_data.drop(columns_to_drop, axis=1)
    prediction_data = prediction_data.drop(columns_to_drop, axis=1)
    prediction_data = prediction_data[train_data.columns]
    scores = {}
    for col in prediction_data.columns:
        if col in continuous_columns:
            score = r2_score(test_data[col], prediction_data[col])
            if score < 0:
                score = 0
            metric = 'R-squared'
        else:
            score = accuracy_score(test_data[col], prediction_data[col])
            metric = 'Accuracy'
        scores[col] = (score, metric)
    average_score = np.mean([score for score, metric in scores.values()])
    average_score = round(average_score * 100, 2)
    table.add_row([file_path, f'{average_score}%'])
    table.add_row([''] * len(table.field_names))
print(table)
# Out:
# Mounted at /content/drive
# 266/266 [==============================] - 2s 3ms/step
# 266/266 [==============================] - 1s 3ms/step
# 266/266 [==============================] - 1s 3ms/step
# 266/266 [==============================] - 2s 3ms/step
# 266/266 [==============================] - 1s 3ms/step
# 266/266 [==============================] - 2s 3ms/step
# 266/266 [==============================] - 2s 3ms/step
# 266/266 [==============================] - 2s 3ms/step
# 266/266 [==============================] - 2s 3ms/step
# 266/266 [==============================] - 1s 2ms/step
# 266/266 [==============================] - 2s 3ms/step
# 266/266 [==============================] - 2s 3ms/step
# 266/266 [==============================] - 2s 3ms/step
# 235/235 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 1s 2ms/step
# 313/313 [==============================] -
content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/iolt_1.csv   |     69.31%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/iolt_2.csv   |     27.18%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/qlt_1.csv    |     60.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/qlt_2.csv    |     60.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/iolt_1.csv   |     67.25%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/iolt_2.csv   |     80.76%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/iolt_1.csv      |     69.39%    |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/iolt_2.csv      |     71.94%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/qlt.csv       |     60.0%     |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/db_bench/mixgraph/iolt.csv      |     61.43%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/db_bench/mixgraph/qlt.csv       |     53.76%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_1/bclt.csv       |     58.6%     |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_1/qlt.csv        |     60.0%     |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_2/bclt.csv       |     62.0%     |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_2/qlt.csv        |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/iolt.csv    |     50.3%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_2/qlt.csv     |     43.68%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_3/qlt.csv     |     44.05%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_4/bclt.csv    |     53.47%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_4/iolt.csv    |     51.9%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_4/qlt.csv     |     43.81%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_5/bclt.csv    |     59.5%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_5/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_6/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_7/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_8/bclt.csv    |     59.66%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_8/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_1.csv   |     64.66%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_2.csv   |     64.64%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_3.csv   |     64.75%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_4.csv   |     64.75%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_5.csv   |     64.76%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_6.csv   |     62.41%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_7.csv   |     63.19%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_8.csv   |     64.9%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/iolt.csv    |     48.49%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/bclt.csv     |     65.55%    |
# |                                                                          |               |
# | /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/bclt_replay.csv |     67.1%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/iolt.csv     |     61.08%    |
# |                                                                          |               |
# | /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/iolt_replay.csv |     45.72%    |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/qlt.csv     |     57.96%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/bclt_1.csv    |     49.36%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/bclt_2.csv    |     50.31%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/iolt.csv     |     51.65%    |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/qlt.csv     |     56.0%     |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_3/qlt.csv     |     58.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_1/bclt.csv   |     58.47%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_1/qlt.csv    |     37.2%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_2/bclt.csv   |     61.95%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_2/qlt.csv    |     32.56%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_3/bclt.csv   |     56.24%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_3/qlt.csv    |     39.71%    |
# |                                                                          |               |
# |            /content/drive/MyDrive/aaa/datasets/redis/bclt.csv            |     80.0%     |
# |                                                                          |               |
# |            /content/drive/MyDrive/aaa/datasets/redis/iolt.csv            |     44.32%    |
# |                                                                          |               |
# |            /content/drive/MyDrive/aaa/datasets/redis/qlt.csv             |     80.0%     |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_1.csv       |     52.25%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_2.csv       |     43.83%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_3.csv       |     42.66%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_4.csv       |     42.2%     |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_5.csv       |     43.14%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_6.csv       |     45.07%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_7.csv       |     44.87%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/ycsb/workloada/qlt_1.csv       |     80.0%     |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/ycsb/workloada/qlt_2.csv       |     61.81%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/ycsb/workloadc/bclt.csv        |     79.75%    |
# |                                                                          |               |
# |        /content/drive/MyDrive/aaa/datasets/ycsb/workloadc/qlt.csv        |     54.12%    |
# |                                                                          |               |
# +--------------------------------------------------------------------------+---------------+

# %%
from google.colab import drive
from keras.layers import Dense, Dropout, Flatten, GRU
from keras.models import Sequential
from natsort import natsorted
from prettytable import PrettyTable
from sklearn.metrics import accuracy_score, r2_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import numpy as np
import os
import pandas as pd
import warnings
drive.mount('/content/drive')
warnings.filterwarnings('ignore')
root_folder = '/content/drive/MyDrive/aaa/datasets'
def find_and_sort_csv_files(folder):
    csv_files = []
    for root, dirs, files in os.walk(folder):
        for file in files:
            if file.endswith('.csv'):
                csv_files.append(os.path.join(root, file))
    csv_files_sorted = natsorted(csv_files)
    return csv_files_sorted
all_csv_files_sorted = find_and_sort_csv_files(root_folder)
feature_name = 'HISTORY' ########################################################
test_ratio_in_percentage = 80 ########################################################
test_ratio = test_ratio_in_percentage / 100 ########################################################
table = PrettyTable()
table.field_names = ["Location", "Average Score"]
for csv_file in all_csv_files_sorted:
    file_path = os.path.join(root_folder, csv_file)
    data = pd.read_csv(file_path)
    data = data.head(int(np.round(len(data) * 0.001)))
    data = data.reset_index()
    test_size = int(np.round(len(data) * test_ratio))
    train_data, test_data = data[:-test_size], data[-test_size:]
    num_columns = train_data.shape[1]
    prediction_indices = range(len(train_data), len(train_data) + test_size)
    prediction_data = pd.DataFrame(prediction_indices, columns=['index'], index=prediction_indices)
    for col in [column for column in train_data.columns if train_data[column].nunique() == 1]:
        prediction_data[col] = pd.Series(train_data[col].iloc[0]).repeat(test_size).values
    columns_not_in_prediction = [col for col in train_data.columns.tolist() if col not in prediction_data.columns.tolist()]
    unique_values_dict = {}
    for col in columns_not_in_prediction:
        unique_values = train_data[col].nunique()
        unique_values_dict[col] = unique_values
    continuous_columns = []
    discrete_columns = []
    for col, unique_values in unique_values_dict.items():
        if unique_values > 500:
            continuous_columns.append(col)
        else:
            discrete_columns.append(col)
    num_past_measurements = 20
    start_index = len(data) - test_size
    for col in columns_not_in_prediction:
        for i in range(1, num_past_measurements + 1):
            data[f'{col}_{i}'] = data[col].shift(i * 25)
            if data[f'{col}_{i}'].dtype == 'int64':
                data[f'{col}_{i}'].fillna(-1, inplace=True)
            elif data[f'{col}_{i}'].dtype == 'float64':
                data[f'{col}_{i}'].fillna(-1.0, inplace=True)
            if data[f'{col}_{i}'].dtype != data[col].dtype:
                data[f'{col}_{i}'] = data[f'{col}_{i}'].astype(data[col].dtype)
            train_data.loc[:start_index, f'{col}_{i}'] = data.loc[:start_index, f'{col}_{i}']
            test_data.loc[:start_index, f'{col}_{i}'] = data.loc[:start_index, f'{col}_{i}']
            prediction_data.loc[start_index:, f'{col}_{i}'] = data.loc[start_index:, f'{col}_{i}']
    num_rows = int(np.round(len(train_data) * 0.05))
    scaler = StandardScaler()
    y_scaler = MinMaxScaler()
    for col in columns_not_in_prediction:
        features = [f'{col}_{i}' for i in range(1, num_columns)]
        X_test = prediction_data[features]
        if col in continuous_columns:
            X_train = train_data[features].values[-num_rows:]
            y_train = train_data[col].values[-num_rows:]
        else:
            X_train = train_data[features].values
            y_train = train_data[col].values
        min_value = y_train.min()
        y_train -= min_value
        y_train_scaled = y_scaler.fit_transform(y_train.reshape(-1, 1))
        X_train_scaled = scaler.fit_transform(X_train)
        X_test_scaled = scaler.transform(X_test)
        X_train_scaled = X_train_scaled.reshape((X_train_scaled.shape[0], X_train_scaled.shape[1], 1))
        X_test_scaled = X_test_scaled.reshape((X_test_scaled.shape[0], X_test_scaled.shape[1], 1))
        model = Sequential()
        model.add(GRU(128, return_sequences=True, input_shape=(X_train_scaled.shape[1], X_train_scaled.shape[2])))
        model.add(Dropout(0.2))
        model.add(GRU(128, return_sequences=True))
        model.add(Dropout(0.2))
        model.add(GRU(128))
        model.add(Dropout(0.2))
        model.add(Flatten())
        if col in continuous_columns:
            model.add(Dense(1, activation='linear'))
            model.compile(loss='mean_squared_error', optimizer='adam')
        else:
            model.add(Dense(len(np.unique(y_train_scaled)), activation='softmax'))
            model.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'], optimizer='adam')
        model.fit(X_train_scaled, y_train_scaled, epochs=10, batch_size=128, verbose=0)
        y_pred_scaled = model.predict(X_test_scaled)
        if col in continuous_columns:
            y_pred = y_scaler.inverse_transform(y_pred_scaled.reshape(-1, 1))
        else:
            y_pred = y_pred_scaled
            y_pred = np.argmax(y_pred, axis=1)
        y_pred += min_value
        y_pred = np.where(y_pred < -1, -1, y_pred)
        if train_data[col].dtype == np.int64:
            y_pred = np.round(y_pred).astype(np.int64)
        prediction_data[col] = y_pred
    columns_to_drop = ['index']
    if columns_not_in_prediction:
        start_index = train_data.columns.get_loc(f'{columns_not_in_prediction[0]}_1')
        end_index = train_data.columns.get_loc(f'{columns_not_in_prediction[-1]}_{num_past_measurements}')
        columns_to_drop.extend(data.columns[start_index:end_index + 1])
    data = data.drop(columns_to_drop, axis=1)
    train_data = train_data.drop(columns_to_drop, axis=1)
    test_data = test_data.drop(columns_to_drop, axis=1)
    prediction_data = prediction_data.drop(columns_to_drop, axis=1)
    prediction_data = prediction_data[train_data.columns]
    scores = {}
    for col in prediction_data.columns:
        if col in continuous_columns:
            score = r2_score(test_data[col], prediction_data[col])
            if score < 0:
                score = 0
            metric = 'R-squared'
        else:
            score = accuracy_score(test_data[col], prediction_data[col])
            metric = 'Accuracy'
        scores[col] = (score, metric)
    average_score = np.mean([score for score, metric in scores.values()])
    average_score = round(average_score * 100, 2)
    table.add_row([file_path, f'{average_score}%'])
    table.add_row([''] * len(table.field_names))
print(table)
# Out:
# Mounted at /content/drive
# 426/426 [==============================] - 2s 3ms/step
# 426/426 [==============================] - 2s 3ms/step
# 426/426 [==============================] - 2s 3ms/step
# 426/426 [==============================] - 2s 3ms/step
# 426/426 [==============================] - 2s 3ms/step
# 426/426 [==============================] - 2s 3ms/step
# 426/426 [==============================] - 2s 3ms/step
# 426/426 [==============================] - 2s 3ms/step
# 426/426 [==============================] - 2s 3ms/step
# 426/426 [==============================] - 2s 3ms/step
# 426/426 [==============================] - 2s 3ms/step
# 426/426 [==============================] - 2s 3ms/step
# 426/426 [==============================] - 2s 3ms/step
# 375/375 [==============================] - 2s 2ms/step
# 375/375 [==============================] - 2s 2ms/step
# 375/375 [==============================] - 2s 2ms/step
# 375/375 [==============================] - 2s 2ms/step
# 501/501 [==============================] - 2s 3ms/step
# 501/501 [==============================] - 2s 3ms/step
# 501/501 [==============================] - 2s 3ms/step
# 501/501 [==============================] - 2s 3ms/step
# 501/501 [==============================] - 2s 3ms/step
# 501/501 [==============================] - 2s 3ms/step
# 501/501 [==============================] - 2s 3ms/step
# 501/501 [==============================] - 2s 3ms/step
# 501/501 [==============================] - 2s 3ms/step
# 501/501 [==============================] - 2s 3ms/step
# 500/500 [==============================] - 2s 2ms/step
# 500/500 [==============================] - 2s 2ms/step
# 501/501 [==============================] - 2s 3ms/step
# 501/501 [==============================] - 2s 3ms/step
# 501/501 [==============================] - 2s 3ms/step
# 501/501 [==============================] - 2s 3ms/step
# 501/501 [==============================] - 2s 3ms/step
# 501/501 [==============================] - 2s 3ms/step
# 501/501 [==============================] - 2s 3ms/step
# 501/501 [==============================] - 2s 3ms/step
# 501/501 [==============================] - 2s 3ms/step
# 501/501 [==============================] - 2s 3ms/step
# 500/500 [==============================] - 2s 2ms/step
# 500/500 [==============================] - 2s 2ms/step
# 7/7 [==============================] - 1s 3ms/step
# 7/7 [==============================] - 1s 3ms/step
# 7/7 [==============================] - 1s 3ms/step
# 7/7 [==============================] - 1s 3ms/step
# 7/7 [==============================] - 1s 3ms/step
# 25/25 [==============================] - 1s 3ms/step
# 25/25 [==============================] - 1s 3ms/step
# 25/25 [==============================] - 1s 3ms/step
# 25/25 [==============================] - 1s 3ms/step
# 92/92 [==============================] - 1s 3ms/step
# 92/92 [==============================] - 1s 3ms/step
# 92/92 [==============================] - 1s 3ms/step
# 92/92 [==============================] - 1s 3ms/step
# 92/92 [==============================] - 1s 3ms/step
# 92/92 [==============================] - 1s 3ms/step
# 92/92 [==============================] - 1s 3ms/step
# 92/92 [==============================] - 1s 3ms/step
# 92/92 [==============================] - 1s 3ms/step
# 92/92 [==============================] - 1s 3ms/step
# 92/92 [==============================] - 1s 3ms/step
# 46/46 [==============================] - 1s 3ms/step
# 46/46 [==============================] - 1s 3ms/step
# 125/125 [==============================] - 1s 3ms/step
# 125/125 [==============================] - 1s 3ms/step
# 125/125 [==============================] - 1s 3ms/step
# 125/125 [==============================] - 1s 3ms/step
# 125/125 [==============================] - 1s 3ms/step
# 125/125 [==============================] - 1s 3ms/step
# 125/125 [==============================] - 1s 3ms/step
# 125/125 [==============================] - 1s 3ms/step
# 125/125 [==============================] - 1s 3ms/step
# 125/125 [==============================] - 1s 3ms/step
# 125/125 [==============================] - 1s 3ms/step
# 63/63 [==============================] -
[==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 3ms/step
# 66/66 [==============================] - 1s 2ms/step
# 66/66 [==============================] - 1s 2ms/step
# 66/66 [==============================] - 1s 3ms/step
# 6/6 [==============================] - 1s 4ms/step
# 6/6 [==============================] - 1s 4ms/step
# 6/6 [==============================] - 1s 4ms/step
# 6/6 [==============================] - 1s 3ms/step
# 6/6 [==============================] - 1s 3ms/step
# 6/6 [==============================] - 1s 3ms/step
# 6/6 [==============================] - 1s 3ms/step
# 50/50 [==============================] - 1s 3ms/step
# 50/50 [==============================] - 1s 3ms/step
# 50/50 [==============================] - 1s 3ms/step
# 50/50 [==============================] - 1s 3ms/step
# 50/50 [==============================] - 1s 3ms/step
# 50/50 [==============================] - 1s 3ms/step
# 50/50 [==============================] - 1s 3ms/step
# 50/50 [==============================] - 1s 2ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 277/277 [==============================] - 2s 3ms/step
# 402/402 [==============================] - 2s 3ms/step
# 402/402 [==============================] - 2s 2ms/step
# 402/402 [==============================] - 2s 3ms/step
# 402/402 [==============================] - 2s 3ms/step
# 402/402 [==============================] - 2s 3ms/step
# 402/402 [==============================] - 2s 3ms/step
# 402/402 [==============================] - 2s 3ms/step
# 79/79 [==============================] - 1s 3ms/step
# 79/79 [==============================] - 1s 3ms/step
# 79/79 [==============================] - 1s 3ms/step
# 79/79 [==============================] - 1s 3ms/step
# 475/475 [==============================] - 2s 2ms/step
# 475/475 [==============================] - 2s 3ms/step
# 475/475 [==============================] - 2s 2ms/step
# 475/475 [==============================] - 2s 2ms/step
# 475/475 [==============================] - 2s 2ms/step
# +--------------------------------------------------------------------------+---------------+
# |                                 Location                                 | Average Score |
# +--------------------------------------------------------------------------+---------------+
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/iolt_1.csv   |     61.15%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/iolt_2.csv   |     38.19%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/qlt_1.csv    |     60.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_1/qlt_2.csv    |     60.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/iolt_1.csv   |     63.71%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/iolt_2.csv   |     71.33%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/fillrandom_2/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/iolt_1.csv      |     61.15%    |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/iolt_2.csv      |     71.84%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/fillseq/qlt.csv       |     60.0%     |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/db_bench/mixgraph/iolt.csv      |     61.04%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/db_bench/mixgraph/qlt.csv       |     54.32%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_1/bclt.csv       |     59.83%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_1/qlt.csv        |     60.0%     |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_2/bclt.csv       |     60.9%     |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/db_bench/read_2/qlt.csv        |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/iolt.csv    |     50.35%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_1/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_2/qlt.csv     |     43.93%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_3/qlt.csv     |     44.07%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_4/bclt.csv    |     56.01%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_4/iolt.csv    |     51.89%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_4/qlt.csv     |     43.95%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_5/bclt.csv    |     57.59%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_5/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_6/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_7/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_8/bclt.csv    |     61.66%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_8/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_1.csv   |     58.66%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_2.csv   |     59.88%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_3.csv   |     59.34%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_4.csv   |     57.96%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_5.csv   |     59.92%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_6.csv   |     57.21%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_7.csv   |     57.85%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/bclt_8.csv   |     56.76%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/iolt.csv    |     48.5%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readrandom_9/qlt.csv     |     60.0%     |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/bclt.csv     |     66.66%    |
# |                                                                          |               |
# | /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/bclt_replay.csv |     67.18%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/iolt.csv     |     61.25%    |
# |                                                                          |               |
# | /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/iolt_replay.csv |     45.8%     |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_1/qlt.csv     |     57.96%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/bclt_1.csv    |     46.93%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/bclt_2.csv    |     50.31%    |
# |                                                                          |               |
# |    /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/iolt.csv     |     51.81%    |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_2/qlt.csv     |     56.0%     |
# |                                                                          |               |
# |     /content/drive/MyDrive/aaa/datasets/db_bench/readwrite_3/qlt.csv     |     58.0%     |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_1/bclt.csv   |     56.47%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_1/qlt.csv    |     35.15%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_2/bclt.csv   |     59.98%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_2/qlt.csv    |     36.91%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_3/bclt.csv   |     56.14%    |
# |                                                                          |               |
# |   /content/drive/MyDrive/aaa/datasets/db_bench/updaterandom_3/qlt.csv    |     39.15%    |
# |                                                                          |               |
# |            /content/drive/MyDrive/aaa/datasets/redis/bclt.csv            |     77.39%    |
# |                                                                          |               |
# |            /content/drive/MyDrive/aaa/datasets/redis/iolt.csv            |     45.0%     |
# |                                                                          |               |
# |            /content/drive/MyDrive/aaa/datasets/redis/qlt.csv             |     80.0%     |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_1.csv       |     57.83%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_2.csv       |     43.77%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_3.csv       |     42.49%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_4.csv       |     42.25%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_5.csv       |     43.25%    |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_6.csv       |     45.0%     |
# |                                                                          |               |
# |      /content/drive/MyDrive/aaa/datasets/ycsb/workloada/bclt_7.csv       |     44.74%    |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/ycsb/workloada/qlt_1.csv       |     80.0%     |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/ycsb/workloada/qlt_2.csv       |     63.4%     |
# |                                                                          |               |
# |       /content/drive/MyDrive/aaa/datasets/ycsb/workloadc/bclt.csv        |     70.33%    |
# |                                                                          |               |
# |        /content/drive/MyDrive/aaa/datasets/ycsb/workloadc/qlt.csv        |     36.47%    |
# |                                                                          |               |
# +--------------------------------------------------------------------------+---------------+
