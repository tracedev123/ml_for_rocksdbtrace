# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
# Open the file
with open('/content/drive/MyDrive/aaa/iolt.txt', 'r') as file:
    # Read the contents
    file_contents = file.read()

# Print the contents
print(file_contents)
